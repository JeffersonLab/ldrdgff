# %% [markdown]
# Let's study the possibility of extraction of CFFs from simulated data, and in particular how to get reliable error bands, using the so-called closure tests, along the lines and ideas introduced by NNPDF collaboration.

# %% [markdown]
# # Initializations

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# We work with `torch` gepard branch!

# %%
import gepard as g
import gepard.plots as gplots
from gepard.fits import GLO15new, AUTIpts, ALUIpts
print('Gepard version = {}'.format(g.__version__))
# Out:
# Gepard version = 0.9.11b0

# %%
import torch
import numpy as np

# %%
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# `torch` branch works only with Neural models, but we want to generate simulated
# data with KM and GK models. So we take `master` Gepard branch, rename
# `gepard -> gmaster` in 3 places in `setup.py` and `setup.cfg`, and by
# `pip install -e .` we install
# official Gepard package under the alternative name `gmaster`.

# %%
import gmaster as gm  # need KM15 for simulated data
from gmaster.fits import par_KM15

# %%
angle = np.pi/4  # simplification instead of harmonics

# %%
## Where stuff to be included in LaTeX goes
PAPER_DIR = '/Users/higuera-admin/Documents/Programs/ldrdgff'
#PAPER_DIR = '/home/marija/Desktop/Doktorski/Teza/Template'

# %% [markdown]
# # Models for generation of artificial data

# %% [markdown]
# We define KM15 model, but for starters we kill all CFFs, save `ImH`.

# %%
class KM15(gm.eff.KellyEFF, gm.gpd.PWNormGPD, gm.cff.HybridFreePoleCFF, gm.dvcs.BM10tw2):
    
    def ReH(self, pt):
        # kills ReH
        return 0

th_KM15_ImH = KM15()
th_KM15_ImH.parameters.update(par_KM15)
th_KM15_ImH.parameters.update({'C':0, 'trv':0, 'rpi':0})  # kills ReE, ImHt, ReHt, ReEt
th_KM15_ImH.name = 'KM15_ImH'

# %%
for cff in th_KM15_ImH.allCFFs:
    print('{} = {}'.format(cff, th_KM15_ImH.predict(g.dset[101][0], observable=cff)))
# Out:
# ImH = 6.744321761721329
# ReH = 0
# ImE = 0.0
# ReE = 0.0
# ImHt = 0.0
# ReHt = 0.0
# ImEt = 0.0
# ReEt = 0.0

# %% [markdown]
# **Second** model has two non-zero CFFs: ImH and ImHt

# %%
class KM15b(gm.eff.KellyEFF, gm.gpd.PWNormGPD, gm.cff.HybridFreePoleCFF, gm.dvcs.BM10tw2):
    
    def ReH(self, pt):
        # kills ReH
        return 0
    
    def ReHt(self, pt):
        # kills ReH
        return 0

th_KM15_ImHHt = KM15b()
th_KM15_ImHHt.parameters.update(par_KM15)
th_KM15_ImHHt.parameters.update({'C':0, 'rpi':0}) 
th_KM15_ImHHt.name = 'KM15_ImH_ImHt'

# %%
for cff in th_KM15_ImHHt.allCFFs:
    print('{} = {}'.format(cff, th_KM15_ImHHt.predict(g.dset[101][0], observable=cff)))
# Out:
# ImH = 6.744321761721329
# ReH = 0
# ImE = 0.0
# ReE = 0.0
# ImHt = 2.436634567882741
# ReHt = 0
# ImEt = 0.0
# ReEt = 0.0

# %% [markdown]
# **Third** model has three non-zero CFFs: ImH, ReE and ImHt

# %%
class KM15c(gm.eff.KellyEFF, gm.gpd.PWNormGPD, gm.cff.HybridFreePoleCFF, gm.dvcs.BM10tw2):
    
    def ReH(self, pt):
        # kills ReH
        return 0
    
    def ReHt(self, pt):
        # kills ReH
        return 0

th_KM15_3 = KM15c()
th_KM15_3.parameters.update(par_KM15)
th_KM15_3.parameters.update({'rpi':0}) 
th_KM15_3.name = 'KM15_3'

# %%
for cff in th_KM15_3.allCFFs:
    print('{} = {}'.format(cff, th_KM15_3.predict(g.dset[101][0], observable=cff)))
# Out:
# ImH = 6.744321761721329
# ReH = 0
# ImE = 0.0
# ReE = 2.3912295942715778
# ImHt = 2.436634567882741
# ReHt = 0
# ImEt = 0.0
# ReEt = 0.0

# %% [markdown]
# **Fourth** model has four non-zero CFFs: ImH, ReH, ReE and ImHt

# %%
class KM15d(gm.eff.KellyEFF, gm.gpd.PWNormGPD, gm.cff.HybridFreePoleCFF, gm.dvcs.BM10tw2):
    
    def ReHt(self, pt):
        # kills ReH
        return 0

th_KM15_4 = KM15d()
th_KM15_4.parameters.update(par_KM15)
th_KM15_4.parameters.update({'rpi':0}) 
th_KM15_4.name = 'KM15_4'

# %%
for cff in th_KM15_4.allCFFs:
    print('{} = {}'.format(cff, th_KM15_4.predict(g.dset[101][0], observable=cff)))
# Out:
# ImH = 6.744321761721329
# ReH = -2.971259892771055
# ImE = 0.0
# ReE = 2.3912295942715778
# ImHt = 2.436634567882741
# ReHt = 0
# ImEt = 0.0
# ReEt = 0.0

# %%
class KM15e(gm.eff.KellyEFF, gm.gpd.PWNormGPD, gm.cff.HybridFreePoleCFF, gm.dvcs.BM10tw2):
    
    def ImH(self, pt):
        return 0
    
    def ReH(self, pt):
        return 0

th_KM15_ReE = KM15e()
th_KM15_ReE.parameters.update(par_KM15)
th_KM15_ReE.parameters.update({'trv':0, 'rpi':0})  # kills ReE, ImHt, ReHt, ReEt
th_KM15_ReE.name = 'KM15_ReE'

# %%
for cff in th_KM15_ReE.allCFFs:
    print('{} = {}'.format(cff, th_KM15_ReE.predict(g.dset[101][0], observable=cff)))
# Out:
# ImH = 0
# ReH = 0
# ImE = 0.0
# ReE = 2.3912295942715778
# ImHt = 0.0
# ReHt = 0.0
# ImEt = 0.0
# ReEt = 0.0

# %%
class KM15f(gm.eff.KellyEFF, gm.gpd.PWNormGPD, gm.cff.HybridFreePoleCFF, gm.dvcs.BM10tw2):
    
    def ReH(self, pt):
        return 0

th_KM15_2 = KM15f()
th_KM15_2.parameters.update(par_KM15)
th_KM15_2.parameters.update({'trv':0, 'rpi':0})  # kills ReE, ImHt, ReHt, ReEt
th_KM15_2.name = 'KM15_ImH+ReE'

# %%
for cff in th_KM15_2.allCFFs:
    print('{} = {}'.format(cff, th_KM15_2.predict(g.dset[101][0], observable=cff)))
# Out:
# ImH = 6.744321761721329
# ReH = 0
# ImE = 0.0
# ReE = 2.3912295942715778
# ImHt = 0.0
# ReHt = 0.0
# ImEt = 0.0
# ReEt = 0.0

# %% [markdown]
# **Model** with five non-zero CFFs: ImH, ReH, ImE, ReE and ImHt

# %%
class KM15g(gm.eff.KellyEFF, gm.gpd.PWNormGPD, gm.cff.HybridFreePoleCFF, gm.dvcs.BM10tw2):
    
    def ReHt(self, pt):
        # kills ReH
        return 0
    
    def ImE(self, pt):
        '''Fake ImE, just made up'''
        return 0.5 * self.ImH(pt)

th_KM15_5 = KM15g()
th_KM15_5.parameters.update(par_KM15)
th_KM15_5.parameters.update({'rpi':0}) 
th_KM15_5.name = 'KM15_4'

# %%
for cff in th_KM15_5.allCFFs:
    print('{} = {}'.format(cff, th_KM15_5.predict(g.dset[101][0], observable=cff)))
# Out:
# ImH = 6.744321761721329
# ReH = -2.971259892771055
# ImE = 3.3721608808606645
# ReE = 2.3912295942715778
# ImHt = 2.436634567882741
# ReHt = 0
# ImEt = 0.0
# ReEt = 0.0

# %% [markdown]
# ## Relative prefactors

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(angle),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      observable='AC')
        pt.id = 4001
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_ReE.predict(pt)
        pt.err = abs(0.1 * pt.val) + 0.0002
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset = g.DataSet(mockset)

# %%
th = th_KM15_ImH

# %%
prefE = np.array([(-pt.t/4/g.constants.Mp2)*th.F2(pt)/th.F1(pt) for pt in mockset])

# %%
prefE.mean(), prefE.std()
# Out:
# (np.float64(0.1221725260041906), np.float64(0.04794123554349669))

# %%
prefHt = np.array([(pt.xB/2)*(th.F1(pt)+th.F2(pt))/th.F1(pt) for pt in mockset])

# %%
prefHt.mean(), prefHt.std()
# Out:
# (np.float64(0.21777982599214343), np.float64(0.07044703031409276))

# %% [markdown]
# # Simulation 1 - XLU only - ImH only - t-dep only - no noise

# %%
mockset = []
for tm in np.linspace(0.1, 0.6, 20):
    pt = g.DataPoint(xB=0.2, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(0.3),
                  process='ep2epgamma', exptype='fixed target', frame='Trento',
                  in1energy=12., in1charge=-1, in1polarization=+1,
                  observable='XLU')
    pt.id = 4001
    pt.year = 2023
    pt.collaboration = 'mock'
    pt.reference = 'mock'
    pt.val = th_KM15_ImH.predict(pt)
    #  pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
    pt.err = 0.2 * pt.val + 0.0001
    mockset.append(pt)
mockset = g.DataSet(mockset)

# %%
fig = gplots.jbod(points=mockset)

# %%
fig.savefig('{}/mock1.pdf'.format(PAPER_DIR))

# %%
class NN(g.model.NeuralModel, g.eff.KellyEFF, g.dvcs.BM10tw2):

    def build_net(self):
            '''Overriding the default architecture and optimizer'''
            nn_model = torch.nn.Sequential(
                    torch.nn.Linear(2, 15),
                    torch.nn.ReLU(),
                    torch.nn.Linear(15, 37),
                    torch.nn.ReLU(),
                    torch.nn.Linear(37, 15),
                    torch.nn.ReLU(),
                    torch.nn.Linear(15, len(self.output_layer))
                )
            optimizer = torch.optim.Rprop(nn_model.parameters(), lr=0.01)
            return nn_model, optimizer

# %%
th = NN(output_layer=['ImH'])
th.name = 'fit'

# %%
f = g.fitter.NeuralFitter(mockset, th, nnets=10, nbatch=80, batchlen=2, regularization=None)

# %%
f.fit()
# Out:
# Epoch   2: train error = 15.5583 test error = 10.9593 -
# Epoch   4: train error = 14.3694 test error = 9.6105 -
# Epoch   6: train error = 10.9181 test error = 6.2340 -
# Epoch   8: train error = 3.2571 test error = 7.0458 +
# Epoch  10: train error = 1.3796 test error = 4.0551 -
# Epoch  12: train error = 1.2854 test error = 3.5302 -
# Epoch  14: train error = 1.1402 test error = 3.3666 -
# Epoch  16: train error = 0.7668 test error = 1.8821 -
# Epoch  18: train error = 0.7882 test error = 1.8030 -
# Epoch  20: train error = 0.6172 test error = 1.4726 -
# Epoch  22: train error = 0.6194 test error = 1.2085 -
# Epoch  24: train error = 0.5852 test error = 1.7396 +
# Epoch  26: train error = 0.5662 test error = 1.2704 +
# Epoch  28: train error = 0.5561 test error = 1.5157 +
# Epoch  30: train error = 0.5493 test error = 1.4304 +
# Epoch  32: train error = 0.5429 test error = 1.3686 +
# No improvement for 5 batches. Stopping early.
# Net 0 --> test_err = 1.2084769010543823
#
# Epoch   2: train error = 8.7977 test error = 12.4966 -
# Epoch   4: train error = 8.1132 test error = 11.3256 -
# Epoch   6: train error = 6.6689 test error = 8.3204 -
# Epoch   8: train error = 3.4759 test error = 3.2068 -
# Epoch  10: train error = 2.8225 test error = 4.4231 +
# Epoch  12: train error = 1.2340 test error = 1.9535 -
# Epoch  14: train error = 1.4302 test error = 0.8969 -
# Epoch  16: train error = 1.1979 test error = 0.8363 -
# Epoch  18: train error = 0.9719 test error = 0.5870 -
# Epoch  20: train error = 1.0260 test error = 0.4210 -
# Epoch  22: train error = 0.8804 test error = 0.3160 -
# Epoch  24: train error = 0.8297 test error = 0.3708 +
# Epoch  26: train error = 0.7744 test error = 0.4410 +
# Epoch  28: train error = 0.7416 test error = 0.5628 +
# Epoch  30: train error = 0.7147 test error = 0.6412 +
# Epoch  32: train error = 0.6815 test error = 0.6763 +
# No improvement for 5 batches. Stopping early.
# Net 1 --> test_err = 0.31602904200553894
#
# Epoch   2: train error = 13.3606 test error = 8.1383 -
# Epoch   4: train error = 13.0719 test error = 7.8285 -
# Epoch   6: train error = 12.3906 test error = 7.0030 -
# Epoch   8: train error = 10.2644 test error = 4.7071 -
# Epoch  10: train error = 4.8334 test error = 0.9351 -
# Epoch  12: train error = 6.1922 test error = 4.0936 +
# Epoch  14: train error = 2.0102 test error = 1.1006 +
# Epoch  16: train error = 1.9802 test error = 0.8998 -
# Epoch  18: train error = 2.1756 test error = 1.4283 +
# Epoch  20: train error = 1.6326 test error = 0.9122 +
# Epoch  22: train error = 1.5453 test error = 0.9421 +
# Epoch  24: train error = 1.5106 test error = 0.9450 +
# Epoch  26: train error = 1.5050 test error = 0.9733 +
# No improvement for 5 batches. Stopping early.
# Net 2 --> test_err = 0.8997529149055481
#
# Epoch   2: train error = 19.0077 test error = 5.3839 -
# Epoch   4: train error = 17.7361 test error = 4.3706 -
# Epoch   6: train error = 14.6867 test error = 2.1468 -
# Epoch   8: train error = 7.8971 test error = 2.4810 +
# Epoch  10: train error = 4.6071 test error = 9.7572 +
# Epoch  12: train error = 1.9811 test error = 2.3709 +
# Epoch  14: train error = 1.2054 test error = 2.1616 +
# Epoch  16: train error = 1.2957 test error = 2.3770 +
# No improvement for 5 batches. Stopping early.
# Net 3 --> test_err = 2.1468241214752197
#
# Epoch   2: train error = 7.2051 test error = 12.1757 -
# Epoch   4: train error = 6.4535 test error = 10.4838 -
# Epoch   6: train error = 4.6093 test error = 6.4392 -
# Epoch   8: train error = 1.2782 test error = 0.6468 -
# Epoch  10: train error = 0.9778 test error = 1.3759 +
# Epoch  12: train error = 0.5490 test error = 0.6971 +
# Epoch  14: train error = 0.4247 test error = 0.9677 +
# Epoch  16: train error = 0.4271 test error = 0.6035 -
# Epoch  18: train error = 0.4048 test error = 0.7227 +
# Epoch  20: train error = 0.3910 test error = 0.8582 +
# Epoch  22: train error = 0.3732 test error = 0.6987 +
# Epoch  24: train error = 0.3587 test error = 0.7839 +
# Epoch  26: train error = 0.3462 test error = 0.7663 +
# No improvement for 5 batches. Stopping early.
# Net 4 --> test_err = 0.6035478711128235
#
# Epoch   2: train error = 10.6335 test error = 11.3406 -
# Epoch   4: train error = 8.8716 test error = 8.3206 -
# Epoch   6: train error = 5.1207 test error = 2.4936 -
# Epoch   8: train error = 2.5494 test error = 1.5524 -
# Epoch  10: train error = 1.6443 test error = 1.4212 -
# Epoch  12: train error = 1.2479 test error = 1.9616 +
# Epoch  14: train error = 1.2531 test error = 2.1431 +
# Epoch  16: train error = 1.1615 test error = 1.7066 +
# Epoch  18: train error = 1.1389 test error = 1.7797 +
# Epoch  20: train error = 1.0961 test error = 1.8586 +
# No improvement for 5 batches. Stopping early.
# Net 5 --> test_err = 1.421242356300354
#
# Epoch   2: train error = 10.5603 test error = 10.5030 -
# Epoch   4: train error = 8.8387 test error = 7.6110 -
# Epoch   6: train error = 5.2806 test error = 2.1843 -
# Epoch   8: train error = 2.2222 test error = 0.7412 -
# Epoch  10: train error = 0.8382 test error = 0.6422 -
# Epoch  12: train error = 0.6469 test error = 1.9055 +
# Epoch  14: train error = 0.5718 test error = 1.0708 +
# Epoch  16: train error = 0.3928 test error = 1.2044 +
# Epoch  18: train error = 0.4309 test error = 0.9025 +
# Epoch  20: train error = 0.3886 test error = 1.0685 +
# No improvement for 5 batches. Stopping early.
# Net 6 --> test_err = 0.6421993374824524
#
# Epoch   2: train error = 11.6119 test error = 7.2870 -
# Epoch   4: train error = 9.7760 test error = 4.8390 -
# Epoch   6: train error = 5.6060 test error = 0.9302 -
# Epoch   8: train error = 1.2296 test error = 2.3047 +
# Epoch  10: train error = 1.1137 test error = 0.4963 -
# Epoch  12: train error = 0.8782 test error = 0.7705 +
# Epoch  14: train error = 0.8904 test error = 0.3946 -
# Epoch  16: train error = 0.8505 test error = 0.7454 +
# Epoch  18: train error = 0.8513 test error = 0.5642 +
# Epoch  20: train error = 0.8353 test error = 0.4276 +
# Epoch  22: train error = 0.8205 test error = 0.4756 +
# Epoch  24: train error = 0.8035 test error = 0.4587 +
# No improvement for 5 batches. Stopping early.
# Net 7 --> test_err = 0.3946446180343628
#
# Epoch   2: train error = 10.7519 test error = 15.4032 -
# Epoch   4: train error = 9.2383 test error = 11.6865 -
# Epoch   6: train error = 6.2449 test error = 4.2852 -
# Epoch   8: train error = 3.6866 test error = 0.2240 -
# Epoch  10: train error = 1.9186 test error = 0.5890 +
# Epoch  12: train error = 2.1553 test error = 2.4264 +
# Epoch  14: train error = 1.7664 test error = 0.7805 +
# Epoch  16: train error = 1.6081 test error = 1.0716 +
# Epoch  18: train error = 1.5987 test error = 0.8188 +
# No improvement for 5 batches. Stopping early.
# Net 8 --> test_err = 0.22400565445423126
#
# Epoch   2: train error = 13.2045 test error = 11.8912 -
# Epoch   4: train error = 11.8257 test error = 9.9797 -
# Epoch   6: train error = 8.4343 test error = 5.9044 -
# Epoch   8: train error = 3.3167 test error = 5.8204 -
# Epoch  10: train error = 2.6817 test error = 2.3649 -
# Epoch  12: train error = 0.7237 test error = 1.7675 -
# Epoch  14: train error = 0.3950 test error = 1.1890 -
# Epoch  16: train error = 0.5201 test error = 1.3578 +
# Epoch  18: train error = 0.4319 test error = 1.6951 +
# Epoch  20: train error = 0.3713 test error = 1.2492 +
# Epoch  22: train error = 0.3908 test error = 1.3617 +
# Epoch  24: train error = 0.3693 test error = 1.5055 +
# No improvement for 5 batches. Stopping early.
# Net 9 --> test_err = 1.1890021562576294

# %%
fig = gplots.jbod(points=mockset, lines=[th], mesh=th)

# %%
fig = gplots.jbod(points=mockset, lines=[th], bands=[th])

# %%
fig.savefig('{}/mock1nn.pdf'.format(PAPER_DIR))

# %%
fig = gplots.CFFt(cffs=['ImH'], lines=[th, th_KM15_ImH], mesh=th)

# %%
fig = gplots.CFFt(cffs=['ImH'], lines=[th, th_KM15_ImH], bands=[th])

# %%
fig.savefig('{}/mock1cff.pdf'.format(PAPER_DIR), bbox_inches='tight', transparent=True, pad_inches=0)

# %% [markdown]
# Perfect (all data is at xB=0.2, so xB=0.1 is not expected to be described well).

# %% [markdown]
# # Simulation 2 - XLU only - ImH only - t-dep only - noise

# %% [markdown]
# ## Data

# %%
mockset = []
for tm in np.linspace(0.1, 0.5, 20):
    pt = g.DataPoint(xB=0.2, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(0.3),
                  process='ep2epgamma', exptype='fixed target', frame='Trento',
                  in1energy=12., in1charge=-1, in1polarization=+1,
                  observable='XLU')
    pt.id = 4001
    pt.year = 2023
    pt.collaboration = 'mock'
    pt.reference = 'mock'
    pt.val = th_KM15_ImH.predict(pt)
    pt.err = 0.1 * pt.val + 0.0002
    pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
    mockset.append(pt)
mockset = g.DataSet(mockset)

# %%
fig = gplots.jbod(points=mockset)

# %%
fig.savefig('{}/ImH-tdep.pdf'.format(PAPER_DIR), bbox_inches='tight', transparent=True, pad_inches=0)

# %% [markdown]
# ## Normal fit

# %%
class NN(g.model.NeuralModel, g.eff.KellyEFF, g.dvcs.BM10tw2):

    def build_net(self):
            '''Overriding the default architecture and optimizer'''
            nn_model = torch.nn.Sequential(
                    torch.nn.Linear(2, 9),
                    torch.nn.ReLU(),
                    torch.nn.Linear(9, 11),
                    torch.nn.ReLU(),
                    torch.nn.Linear(11, len(self.output_layer))
                )
            optimizer = torch.optim.Rprop(nn_model.parameters(), lr=0.01)
            return nn_model, optimizer

# %%
th = NN(output_layer=['ImH'])
th.name = 'fit'

# %%
f = g.fitter.NeuralFitter(mockset, th, nnets=5, nbatch=40, regularization='L2', lx_lambda=0.001)

# %%
f.fit()
# Out:
# /Users/higuera-admin/Documents/Programs/ldrdgff/gepard/src/gepard/model.py:236: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = self.standardize(torch.tensor(input_layer, dtype=torch.float32),
# Epoch   5: train error = 20.0709 test error = 15.3399 -
# Epoch  10: train error = 10.9471 test error = 3.8042 -
# Epoch  15: train error = 2.5104 test error = 0.4925 -
# Epoch  20: train error = 1.5595 test error = 0.5655 +
# Epoch  25: train error = 1.4142 test error = 0.5407 +
# Epoch  30: train error = 1.3832 test error = 0.6406 +
# Epoch  35: train error = 1.3762 test error = 0.6614 +
# Epoch  40: train error = 1.3703 test error = 0.6574 +
# No improvement for 5 batches. Stopping early.
# Net 0 --> test_err = 0.49252161383628845
#
# Epoch   5: train error = 14.3466 test error = 18.5614 -
# Epoch  10: train error = 8.5174 test error = 9.0622 -
# Epoch  15: train error = 3.2106 test error = 1.6592 -
# Epoch  20: train error = 0.9886 test error = 1.5913 -
# Epoch  25: train error = 0.8313 test error = 1.7036 +
# Epoch  30: train error = 0.8015 test error = 1.7225 +
# Epoch  35: train error = 0.7768 test error = 1.7417 +
# Epoch  40: train error = 0.7656 test error = 1.7235 +
# Epoch  45: train error = 0.7612 test error = 1.7350 +
# No improvement for 5 batches. Stopping early.
# Net 1 --> test_err = 1.5913058519363403
#
# Epoch   5: train error = 24.4009 test error = 17.8179 -
# Epoch  10: train error = 20.9415 test error = 14.1381 -
# Epoch  15: train error = 7.5768 test error = 4.3391 -
# Epoch  20: train error = 1.0715 test error = 4.9338 +
# Epoch  25: train error = 1.0980 test error = 2.8391 -
# Epoch  30: train error = 0.9923 test error = 2.7264 -
# Epoch  35: train error = 0.9395 test error = 2.8436 +
# Epoch  40: train error = 0.8587 test error = 3.1977 +
# Epoch  45: train error = 0.8294 test error = 3.4114 +
# Epoch  50: train error = 0.8188 test error = 3.4957 +
# Epoch  55: train error = 0.8121 test error = 3.5812 +
# No improvement for 5 batches. Stopping early.
# Net 2 --> test_err = 2.7263619899749756
#
# Epoch   5: train error = 20.8784 test error = 16.9574 -
# Epoch  10: train error = 10.4970 test error = 3.2381 -
# Epoch  15: train error = 2.8565 test error = 1.5486 -
# Epoch  20: train error = 2.8400 test error = 2.5106 +
# Epoch  25: train error = 2.5325 test error = 2.3621 +
# Epoch  30: train error = 2.4232 test error = 2.4023 +
# Epoch  35: train error = 2.2338 test error = 2.0498 +
# Epoch  40: train error = 2.0348 test error = 1.4852 -
# Epoch  45: train error = 1.8586 test error = 1.4854 +
# Epoch  50: train error = 1.7399 test error = 1.6376 +
# Epoch  55: train error = 1.6556 test error = 1.6256 +
# Epoch  60: train error = 1.5222 test error = 1.7216 +
# Epoch  65: train error = 1.4349 test error = 1.8289 +
# No improvement for 5 batches. Stopping early.
# Net 3 --> test_err = 1.4852269887924194
#
# Epoch   5: train error = 17.6329 test error = 30.2976 -
# Epoch  10: train error = 7.7507 test error = 9.2816 -
# Epoch  15: train error = 1.3926 test error = 3.7071 -
# Epoch  20: train error = 1.3389 test error = 2.7342 -
# Epoch  25: train error = 1.2638 test error = 2.5994 -
# Epoch  30: train error = 1.1792 test error = 2.6356 +
# Epoch  35: train error = 1.1060 test error = 2.5796 -
# Epoch  40: train error = 1.0485 test error = 2.4201 -
# Epoch  45: train error = 0.9883 test error = 2.3840 -
# Epoch  50: train error = 0.9161 test error = 2.2130 -
# Epoch  55: train error = 0.8779 test error = 2.5703 +
# Epoch  60: train error = 0.8491 test error = 2.8279 +
# Epoch  65: train error = 0.8191 test error = 2.8022 +
# Epoch  70: train error = 0.8006 test error = 2.8342 +
# Epoch  75: train error = 0.7937 test error = 2.5740 +
# No improvement for 5 batches. Stopping early.
# Net 4 --> test_err = 2.2130467891693115

# %%
th.chisq(mockset)
# Out:
# (tensor(13.9755), 20, tensor(0.8317))

# %%
fig = gplots.jbod(points=mockset, lines=[th], mesh=th)

# %%
fig.savefig('{}/ImH-mesh.pdf'.format(PAPER_DIR), bbox_inches='tight', transparent=True, pad_inches=0)

# %%
fig = gplots.jbod(points=mockset, lines=[th], bands=[th])

# %%
fig.savefig('{}/mock2nn.pdf'.format(PAPER_DIR), bbox_inches='tight', transparent=True, pad_inches=0)

# %%
fig = gplots.CFFt(cffs=['ImH'], lines=[th, th_KM15_ImH], mesh=th)

# %%
fig = gplots.CFFt(cffs=['ImH'], lines=[th, th_KM15_ImH], bands=[th])

# %%
fig.savefig('{}/mock2cff.pdf'.format(PAPER_DIR), bbox_inches='tight', transparent=True, pad_inches=0)

# %% [markdown]
# # Simulation 3 - XLU only - ImH only - xB and t-dep - noise

# %% [markdown]
# ## Dataset

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(0.3),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      observable='XLU')
        pt.id = 4001
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_ImH.predict(pt)
        pt.err = 0.1 * pt.val + 0.0002
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset = g.DataSet(mockset)

# %%
fig = gplots.jbod(points=[mockset[6:12], mockset[12:18], mockset[18:24]] )

# %%
mockset[6].xB, mockset[12].xB, mockset[18].xB
# Out:
# (np.float64(0.15), np.float64(0.2), np.float64(0.25))

# %% [markdown]
# ## Fit

# %%
class NN(g.model.NeuralModel, g.eff.KellyEFF, g.dvcs.BM10tw2):

    def build_net(self):
            '''Overriding the default architecture and optimizer'''
            nn_model = torch.nn.Sequential(
                    torch.nn.Linear(2, 23),
                    torch.nn.ReLU(),
                    torch.nn.Linear(23, 27),
                    torch.nn.ReLU(),
                    torch.nn.Linear(27, len(self.output_layer))
                    # torch.nn.Sigmoid(),
                )
            optimizer = torch.optim.Rprop(nn_model.parameters(), lr=0.01)
            return nn_model, optimizer

# %%
th = NN(output_layer=['ImH'])
th.name = 'fit'

# %%
f = g.fitter.NeuralFitter(mockset, th, nnets=10, batchlen=5, regularization='L2', lx_lambda=0.001)

# %%
f.fit()
# Out:
# /Users/higuera-admin/Documents/Programs/ldrdgff/gepard/src/gepard/model.py:236: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = self.standardize(torch.tensor(input_layer, dtype=torch.float32),
# Epoch   5: train error = 26.1765 test error = 18.8990 -
# Epoch  10: train error = 3.2650 test error = 4.1283 -
# Epoch  15: train error = 1.2781 test error = 4.9212 +
# Epoch  20: train error = 0.9582 test error = 4.3315 +
# Epoch  25: train error = 0.5535 test error = 4.7726 +
# Epoch  30: train error = 0.3934 test error = 5.4064 +
# Epoch  35: train error = 0.2840 test error = 5.5720 +
# No improvement for 5 batches. Stopping early.
# Net 0 --> test_err = 4.128271102905273
#
# Epoch   5: train error = 31.7627 test error = 11.8053 -
# Epoch  10: train error = 7.7696 test error = 15.8680 +
# Epoch  15: train error = 2.6296 test error = 5.7012 -
# Epoch  20: train error = 1.7325 test error = 3.3085 -
# Epoch  25: train error = 1.3871 test error = 2.9734 -
# Epoch  30: train error = 1.2217 test error = 3.1374 +
# Epoch  35: train error = 1.1225 test error = 3.3566 +
# Epoch  40: train error = 1.0433 test error = 3.3761 +
# Epoch  45: train error = 1.0070 test error = 3.6652 +
# Epoch  50: train error = 0.9615 test error = 3.6527 +
# No improvement for 5 batches. Stopping early.
# Net 1 --> test_err = 2.9734115600585938
#
# Epoch   5: train error = 24.0774 test error = 18.1290 -
# Epoch  10: train error = 7.1173 test error = 9.1379 -
# Epoch  15: train error = 2.7632 test error = 5.0359 -
# Epoch  20: train error = 1.5744 test error = 3.5403 -
# Epoch  25: train error = 1.4346 test error = 3.1084 -
# Epoch  30: train error = 1.1889 test error = 2.6020 -
# Epoch  35: train error = 0.9085 test error = 2.5491 -
# Epoch  40: train error = 0.6178 test error = 3.4292 +
# Epoch  45: train error = 0.5073 test error = 3.6500 +
# Epoch  50: train error = 0.4087 test error = 3.9467 +
# Epoch  55: train error = 0.3214 test error = 3.9501 +
# Epoch  60: train error = 0.2419 test error = 3.9828 +
# No improvement for 5 batches. Stopping early.
# Net 2 --> test_err = 2.5491065979003906
#
# Epoch   5: train error = 21.1864 test error = 14.5968 -
# Epoch  10: train error = 6.5686 test error = 3.2253 -
# Epoch  15: train error = 2.8676 test error = 1.8552 -
# Epoch  20: train error = 2.1951 test error = 2.1046 +
# Epoch  25: train error = 1.6798 test error = 3.1008 +
# Epoch  30: train error = 1.4209 test error = 4.2142 +
# Epoch  35: train error = 1.2956 test error = 4.6028 +
# Epoch  40: train error = 1.1656 test error = 4.3780 +
# No improvement for 5 batches. Stopping early.
# Net 3 --> test_err = 1.855183720588684
#
# Epoch   5: train error = 32.7970 test error = 8.4283 -
# Epoch  10: train error = 9.1270 test error = 8.2899 -
# Epoch  15: train error = 2.9847 test error = 0.9329 -
# Epoch  20: train error = 1.9712 test error = 1.0757 +
# Epoch  25: train error = 1.0671 test error = 2.7009 +
# Epoch  30: train error = 0.9509 test error = 2.4671 +
# Epoch  35: train error = 0.8989 test error = 2.8099 +
# Epoch  40: train error = 0.7925 test error = 3.7248 +
# No improvement for 5 batches. Stopping early.
# Net 4 --> test_err = 0.9328926801681519
#
# Epoch   5: train error = 29.6463 test error = 29.3012 -
# Epoch  10: train error = 6.7305 test error = 7.0039 -
# Epoch  15: train error = 1.2696 test error = 5.1368 -
# Epoch  20: train error = 1.0025 test error = 5.5847 +
# Epoch  25: train error = 0.8617 test error = 5.5957 +
# Epoch  30: train error = 0.7328 test error = 5.9705 +
# Epoch  35: train error = 0.6673 test error = 5.6950 +
# Epoch  40: train error = 0.6007 test error = 5.0005 -
# Epoch  45: train error = 0.5152 test error = 4.3599 -
# Epoch  50: train error = 0.4874 test error = 4.1797 -
# Epoch  55: train error = 0.4642 test error = 3.9178 -
# Epoch  60: train error = 0.4301 test error = 3.5522 -
# Epoch  65: train error = 0.4118 test error = 3.7002 +
# Epoch  70: train error = 0.4002 test error = 3.6883 +
# Epoch  75: train error = 0.3859 test error = 3.5599 +
# Epoch  80: train error = 0.3656 test error = 3.5827 +
# Epoch  85: train error = 0.3433 test error = 3.5249 -
# Epoch  90: train error = 0.3284 test error = 3.3411 -
# Epoch  95: train error = 0.3145 test error = 3.2876 -
# Epoch 100: train error = 0.3016 test error = 3.2387 -Net 5 --> test_err = 3.2387499809265137
#
# Epoch   5: train error = 32.4755 test error = 6.7942 -
# Epoch  10: train error = 6.8013 test error = 10.0249 +
# Epoch  15: train error = 1.7005 test error = 2.7985 -
# Epoch  20: train error = 1.1807 test error = 3.2254 +
# Epoch  25: train error = 0.9634 test error = 3.3495 +
# Epoch  30: train error = 0.8453 test error = 3.2660 +
# Epoch  35: train error = 0.7244 test error = 3.2316 +
# Epoch  40: train error = 0.5577 test error = 3.0003 +
# No improvement for 5 batches. Stopping early.
# Net 6 --> test_err = 2.7984673976898193
#
# Epoch   5: train error = 28.8975 test error = 20.3562 -
# Epoch  10: train error = 7.4709 test error = 1.5767 -
# Epoch  15: train error = 1.6203 test error = 1.5310 -
# Epoch  20: train error = 0.9351 test error = 1.2290 -
# Epoch  25: train error = 0.5523 test error = 1.5750 +
# Epoch  30: train error = 0.3316 test error = 2.3847 +
# Epoch  35: train error = 0.2551 test error = 2.5344 +
# Epoch  40: train error = 0.2068 test error = 2.7499 +
# Epoch  45: train error = 0.1780 test error = 2.9008 +
# No improvement for 5 batches. Stopping early.
# Net 7 --> test_err = 1.2290382385253906
#
# Epoch   5: train error = 22.2692 test error = 13.4748 -
# Epoch  10: train error = 4.9165 test error = 3.6889 -
# Epoch  15: train error = 2.5332 test error = 2.3518 -
# Epoch  20: train error = 1.6994 test error = 3.0065 +
# Epoch  25: train error = 1.3222 test error = 3.8259 +
# Epoch  30: train error = 0.9255 test error = 4.9472 +
# Epoch  35: train error = 0.7163 test error = 4.6269 +
# Epoch  40: train error = 0.4775 test error = 3.8608 +
# No improvement for 5 batches. Stopping early.
# Net 8 --> test_err = 2.3518025875091553
#
# Epoch   5: train error = 29.2137 test error = 8.1451 -
# Epoch  10: train error = 6.8777 test error = 11.6978 +
# Epoch  15: train error = 1.8699 test error = 4.4737 -
# Epoch  20: train error = 1.1826 test error = 3.1950 -
# Epoch  25: train error = 0.7068 test error = 3.2331 +
# Epoch  30: train error = 0.3619 test error = 4.0454 +
# Epoch  35: train error = 0.1627 test error = 4.0614 +
# Epoch  40: train error = 0.0816 test error = 3.7423 +
# Epoch  45: train error = 0.0716 test error = 3.5700 +
# No improvement for 5 batches. Stopping early.
# Net 9 --> test_err = 3.1950361728668213

# %%
th.chisq(mockset)
# Out:
# (tensor(8.4864), 24, tensor(0.9985))

# %%
fig = gplots.jbod(points=[mockset[6:12], mockset[12:18], mockset[18:24]], lines=[th], mesh=th)

# %%
fig.savefig('{}XLU-mesh.pdf'.format(PAPER_DIR), bbox_inches='tight', transparent=True, pad_inches=0)

# %%
fig = gplots.CFFt(cffs=['ImH'], lines=[th, th_KM15_ImH], mesh=th)

# %%
fig = gplots.CFFt(cffs=['ImH'], lines=[th, th_KM15_ImH], bands=[th])

# %%
## fig.savefig('{}ImH-xt.pdf'.format(PAPER_DIR), bbox_inches='tight', transparent=True, pad_inches=0)

# %% [markdown]
# # Simulation 3b - AC only - ReE only - xB and t-dep - noise

# %% [markdown]
# ## Dataset

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(0.3),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      observable='AC')
        pt.id = 4001
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_ReE.predict(pt)
        pt.err = abs(0.1 * pt.val) + 0.0002
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset = g.DataSet(mockset)

# %%
fig = gplots.jbod(points=mockset[6:])

# %% [markdown]
# ## Fit

# %%
class NN(g.model.NeuralModel, g.eff.KellyEFF, g.dvcs.BM10tw2):

    def build_net(self):
            '''Overriding the default architecture and optimizer'''
            nn_model = torch.nn.Sequential(
                    torch.nn.Linear(2, 13),
                    torch.nn.ReLU(),
                    torch.nn.Linear(13, 17),
                    torch.nn.ReLU(),
                    torch.nn.Linear(17, len(self.output_layer))
                    # torch.nn.Sigmoid(),
                )
            optimizer = torch.optim.Rprop(nn_model.parameters(), lr=0.01)
            return nn_model, optimizer

# %%
th = NN(output_layer=['ReE'])
th.name = 'fit'

# %%
f = g.fitter.NeuralFitter(mockset, th, nnets=3, batchlen=5, regularization='L2', lx_lambda=0.001)

# %%
f.fit()
# Out:
# /Users/higuera-admin/Documents/Programs/ldrdgff/gepard/src/gepard/model.py:236: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = self.standardize(torch.tensor(input_layer, dtype=torch.float32),
# Epoch   5: train error = 68.3067 test error = 17.4870 -
# Epoch  10: train error = 10.8977 test error = 9.4810 -
# Epoch  15: train error = 3.9088 test error = 0.7816 -
# Epoch  20: train error = 1.8246 test error = 2.9493 +
# Epoch  25: train error = 1.0062 test error = 3.7200 +
# Epoch  30: train error = 0.8333 test error = 4.7287 +
# Epoch  35: train error = 0.6785 test error = 4.2901 +
# Epoch  40: train error = 0.5285 test error = 4.3126 +
# No improvement for 5 batches. Stopping early.
# Net 0 --> test_err = 0.7816020846366882
#
# Epoch   5: train error = 33.0093 test error = 22.8496 -
# Epoch  10: train error = 2.7533 test error = 3.4072 -
# Epoch  15: train error = 1.0019 test error = 2.0006 -
# Epoch  20: train error = 0.7570 test error = 2.2134 +
# Epoch  25: train error = 0.5014 test error = 2.4339 +
# Epoch  30: train error = 0.3662 test error = 2.6756 +
# Epoch  35: train error = 0.2299 test error = 2.8032 +
# Epoch  40: train error = 0.1508 test error = 2.9774 +
# No improvement for 5 batches. Stopping early.
# Net 1 --> test_err = 2.0006306171417236
#
# Epoch   5: train error = 51.9824 test error = 51.8355 -
# Epoch  10: train error = 16.5102 test error = 16.7986 -
# Epoch  15: train error = 1.7358 test error = 4.0722 -
# Epoch  20: train error = 1.2141 test error = 2.4001 -
# Epoch  25: train error = 0.8406 test error = 2.3077 -
# Epoch  30: train error = 0.5847 test error = 2.3624 +
# Epoch  35: train error = 0.4865 test error = 2.8107 +
# Epoch  40: train error = 0.4462 test error = 2.5020 +
# Epoch  45: train error = 0.4050 test error = 2.3575 +
# Epoch  50: train error = 0.3618 test error = 2.2552 -
# Epoch  55: train error = 0.3137 test error = 2.2638 +
# Epoch  60: train error = 0.2692 test error = 2.2473 -
# Epoch  65: train error = 0.2284 test error = 2.4942 +
# Epoch  70: train error = 0.2023 test error = 2.6376 +
# Epoch  75: train error = 0.1657 test error = 2.8235 +
# Epoch  80: train error = 0.1499 test error = 2.8460 +
# Epoch  85: train error = 0.1421 test error = 2.8592 +
# No improvement for 5 batches. Stopping early.
# Net 2 --> test_err = 2.247349262237549

# %%
th.chisq(mockset)
# Out:
# (tensor(18.0260), 24, tensor(0.8017))

# %%
fig = gplots.jbod(points=mockset[:18], lines=[th], mesh=th)

# %%
fig = gplots.CFFt(cffs=['ReE'], lines=[th, th_KM15_ReE], mesh=th)

# %%
fig = gplots.CFFt(cffs=['ReE'], lines=[th, th_KM15_ReE], bands=[th])

# %% [markdown]
# # Simulation 4 - (XLU + XUU) - (ImH + ImE=0) - (xB + t-dep)

# %% [markdown]
# ## Dataset

# %% [markdown]
# We still keep ImE=0 and see if model will recognize it.

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(0.3),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      observable='XLU')
        pt.id = 4001
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_ImH.predict(pt)
        pt.err = 0.1 * pt.val + 0.0002
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset_XLU = g.DataSet(mockset)

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(0.3),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      observable='XUU')
        pt.id = 4001
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_ImH.predict(pt)
        pt.err = 0.1 * pt.val + 0.001
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset_XUU = g.DataSet(mockset)

# %%
fig = gplots.jbod(points=mockset_XUU[18:])

# %% [markdown]
# ## Fit

# %%
class NN(g.model.NeuralModel, g.eff.KellyEFF, g.dvcs.BM10tw2):

    def build_net(self):
            '''Overriding the default architecture and optimizer'''
            nn_model = torch.nn.Sequential(
                    torch.nn.Linear(2, 13),
                    torch.nn.ReLU(),
                    torch.nn.Linear(13, 17),
                    torch.nn.ReLU(),
                    torch.nn.Linear(17, len(self.output_layer)),
                )
            optimizer = torch.optim.Rprop(nn_model.parameters(), lr=0.01)
            return nn_model, optimizer

# %%
th = NN(output_layer=['ImH', 'ImE'])
th.name = 'fit'

# %%
f = g.fitter.NeuralFitter([mockset_XLU, mockset_XUU],
                          th, nnets=5, nbatch=50, batchlen=2, regularization='L2', lx_lambda=0.001)

# %%
f.fit()
# Out:
# Epoch   2: train error = 19.0806 test error = 20.6136 -
# Epoch   4: train error = 18.1658 test error = 19.4358 -
# Epoch   6: train error = 16.8020 test error = 17.4364 -
# Epoch   8: train error = 14.2736 test error = 13.4720 -
# Epoch  10: train error = 9.3880 test error = 6.2282 -
# Epoch  12: train error = 3.1647 test error = 9.4989 +
# Epoch  14: train error = 4.0289 test error = 4.1535 -
# Epoch  16: train error = 2.2781 test error = 3.3843 -
# Epoch  18: train error = 1.6482 test error = 3.7464 +
# Epoch  20: train error = 1.5601 test error = 1.8536 -
# Epoch  22: train error = 1.5118 test error = 2.4822 +
# Epoch  24: train error = 1.4430 test error = 2.1301 +
# Epoch  26: train error = 1.3793 test error = 1.9909 +
# Epoch  28: train error = 1.3291 test error = 1.8812 +
# Epoch  30: train error = 1.2806 test error = 1.6303 -
# Epoch  32: train error = 1.2415 test error = 1.7268 +
# Epoch  34: train error = 1.2053 test error = 1.6051 -
# Epoch  36: train error = 1.1888 test error = 1.7122 +
# Epoch  38: train error = 1.1727 test error = 1.6647 +
# Epoch  40: train error = 1.1571 test error = 1.6584 +
# Epoch  42: train error = 1.1392 test error = 1.6936 +
# Epoch  44: train error = 1.1191 test error = 1.7178 +
# No improvement for 5 batches. Stopping early.
# Net 0 --> test_err = 1.6051440238952637
#
# Epoch   2: train error = 17.1733 test error = 24.5925 -
# Epoch   4: train error = 16.6970 test error = 23.8835 -
# Epoch   6: train error = 15.9889 test error = 22.7442 -
# Epoch   8: train error = 14.5461 test error = 20.3138 -
# Epoch  10: train error = 11.1993 test error = 15.7463 -
# Epoch  12: train error = 7.2376 test error = 13.8193 -
# Epoch  14: train error = 5.3327 test error = 8.7160 -
# Epoch  16: train error = 3.2441 test error = 4.3570 -
# Epoch  18: train error = 2.1805 test error = 3.3364 -
# Epoch  20: train error = 1.8731 test error = 2.6836 -
# Epoch  22: train error = 1.7365 test error = 2.6048 -
# Epoch  24: train error = 1.4625 test error = 3.0080 +
# Epoch  26: train error = 1.3622 test error = 2.6619 +
# Epoch  28: train error = 1.3253 test error = 2.5529 -
# Epoch  30: train error = 1.2607 test error = 2.5904 +
# Epoch  32: train error = 1.2171 test error = 2.7511 +
# Epoch  34: train error = 1.1747 test error = 2.7199 +
# Epoch  36: train error = 1.1385 test error = 2.6497 +
# Epoch  38: train error = 1.1096 test error = 2.7104 +
# No improvement for 5 batches. Stopping early.
# Net 1 --> test_err = 2.5529379844665527
#
# Epoch   2: train error = 23.2050 test error = 16.9434 -
# Epoch   4: train error = 22.1790 test error = 15.9219 -
# Epoch   6: train error = 20.5292 test error = 13.9520 -
# Epoch   8: train error = 17.2549 test error = 9.8464 -
# Epoch  10: train error = 11.0600 test error = 8.5801 -
# Epoch  12: train error = 7.6470 test error = 5.8979 -
# Epoch  14: train error = 3.8741 test error = 2.6437 -
# Epoch  16: train error = 2.2637 test error = 2.5608 -
# Epoch  18: train error = 2.0238 test error = 2.3681 -
# Epoch  20: train error = 1.7022 test error = 2.5702 +
# Epoch  22: train error = 1.4591 test error = 2.6224 +
# Epoch  24: train error = 1.2475 test error = 3.6035 +
# Epoch  26: train error = 1.2086 test error = 3.8484 +
# Epoch  28: train error = 1.1565 test error = 3.7772 +
# No improvement for 5 batches. Stopping early.
# Net 2 --> test_err = 2.3680856227874756
#
# Epoch   2: train error = 14.1836 test error = 34.1286 -
# Epoch   4: train error = 13.2521 test error = 32.8535 -
# Epoch   6: train error = 12.1933 test error = 30.9498 -
# Epoch   8: train error = 10.3573 test error = 27.1587 -
# Epoch  10: train error = 6.6314 test error = 19.3099 -
# Epoch  12: train error = 1.9725 test error = 14.3419 -
# Epoch  14: train error = 2.4232 test error = 10.2889 -
# Epoch  16: train error = 1.2618 test error = 6.9160 -
# Epoch  18: train error = 0.9414 test error = 4.3250 -
# Epoch  20: train error = 0.9015 test error = 3.8522 -
# Epoch  22: train error = 0.8911 test error = 4.2527 +
# Epoch  24: train error = 0.8604 test error = 3.7971 -
# Epoch  26: train error = 0.8403 test error = 3.7319 -
# Epoch  28: train error = 0.8163 test error = 3.6136 -
# Epoch  30: train error = 0.7961 test error = 3.6654 +
# Epoch  32: train error = 0.7793 test error = 3.7557 +
# Epoch  34: train error = 0.7716 test error = 3.6235 +
# Epoch  36: train error = 0.7670 test error = 3.5694 -
# Epoch  38: train error = 0.7603 test error = 3.4866 -
# Epoch  40: train error = 0.7550 test error = 3.5307 +
# Epoch  42: train error = 0.7470 test error = 3.4289 -
# Epoch  44: train error = 0.7390 test error = 3.3994 -
# Epoch  46: train error = 0.7333 test error = 3.3250 -
# Epoch  48: train error = 0.7268 test error = 3.4944 +
# Epoch  50: train error = 0.7187 test error = 3.5061 +
# Epoch  52: train error = 0.7077 test error = 3.4566 +
# Epoch  54: train error = 0.6947 test error = 3.4507 +
# Epoch  56: train error = 0.6834 test error = 3.6422 +
# No improvement for 5 batches. Stopping early.
# Net 3 --> test_err = 3.3250162601470947
#
# Epoch   2: train error = 15.4515 test error = 31.7841 -
# Epoch   4: train error = 14.4194 test error = 29.9607 -
# Epoch   6: train error = 12.6474 test error = 26.2786 -
# Epoch   8: train error = 9.3959 test error = 18.5328 -
# Epoch  10: train error = 6.4275 test error = 9.9049 -
# Epoch  12: train error = 3.7686 test error = 5.8194 -
# Epoch  14: train error = 2.2042 test error = 3.6476 -
# Epoch  16: train error = 1.6071 test error = 2.1663 -
# Epoch  18: train error = 1.5697 test error = 2.1311 -
# Epoch  20: train error = 1.5219 test error = 2.2210 +
# Epoch  22: train error = 1.4506 test error = 1.9357 -
# Epoch  24: train error = 1.4156 test error = 2.0255 +
# Epoch  26: train error = 1.3828 test error = 1.9605 +
# Epoch  28: train error = 1.3585 test error = 1.9358 +
# Epoch  30: train error = 1.3401 test error = 1.9188 -
# Epoch  32: train error = 1.3257 test error = 1.9232 +
# Epoch  34: train error = 1.3109 test error = 1.9620 +
# Epoch  36: train error = 1.2989 test error = 1.9152 -
# Epoch  38: train error = 1.2877 test error = 1.9733 +
# Epoch  40: train error = 1.2752 test error = 1.9793 +
# Epoch  42: train error = 1.2654 test error = 2.0652 +
# Epoch  44: train error = 1.2590 test error = 2.1775 +
# Epoch  46: train error = 1.2526 test error = 2.1467 +
# No improvement for 5 batches. Stopping early.
# Net 4 --> test_err = 1.9152166843414307

# %%
print('chisq_XLU = {}'.format(th.chisq(mockset_XLU)))
print('chisq_XUU = {}'.format(th.chisq(mockset_XUU)))
# Out:
# chisq_XLU = (tensor(9.8760), 24, tensor(0.9950))
# chisq_XUU = (tensor(20.2270), 24, tensor(0.6838))

# %%
fig = gplots.jbod(points=mockset_XUU[:18], lines=[th], mesh=th)

# %%
fig = gplots.jbod(points=mockset_XLU[:18], lines=[th], mesh=th)

# %%
fig = gplots.CFFt(cffs=['ImH', 'ImE'], lines=[th, th_KM15_ImH], mesh=th)

# %%
fig = gplots.CFFt(cffs=['ImH', 'ImE'], lines=[th, th_KM15_ImH], bands=[th])

# %% [markdown]
# Works very nice ... Some difficulty in reproducing strong rise of ImH with small xB and small -t is maybe due to MC replicas sometimes excluding this extreme point from the training set, so there is overal bias towards functions that are *not* extremal at the edges of data region.

# %% [markdown]
# # Simulation 5 - (XLU + XUU) - (ImH + ImHt) - (xB + t-dep)

# %% [markdown]
# ## Dataset

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(0.3),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      observable='XLU')
        pt.id = 4001
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_ImHHt.predict(pt)
        pt.err = 0.1 * pt.val + 0.0002
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset_XLU = g.DataSet(mockset)

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(0.3),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      observable='XUU')
        pt.id = 4001
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_ImHHt.predict(pt)
        pt.err = 0.1 * pt.val + 0.001
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset_XUU = g.DataSet(mockset)

# %%
fig = gplots.jbod(points=mockset_XUU[18:])

# %% [markdown]
# ## Fit

# %%
class NN(g.model.NeuralModel, g.eff.KellyEFF, g.dvcs.BM10tw2):

    def build_net(self):
            '''Overriding the default architecture and optimizer'''
            nn_model = torch.nn.Sequential(
                    torch.nn.Linear(2, 13),
                    torch.nn.ReLU(),
                    torch.nn.Linear(13, 17),
                    torch.nn.ReLU(),
                    torch.nn.Linear(17, len(self.output_layer)),
                )
            optimizer = torch.optim.Rprop(nn_model.parameters(), lr=0.01)
            return nn_model, optimizer

# %%
th = NN(output_layer=['ImH', 'ImHt'])
th.name = 'fit'

# %%
f = g.fitter.NeuralFitter([mockset_XLU, mockset_XUU],
                          th, nnets=5, nbatch=50, batchlen=2, regularization='L2', lx_lambda=0.001)

# %%
f.fit()
# Out:
# Epoch   2: train error = 19.2399 test error = 20.7609 -
# Epoch   4: train error = 18.1549 test error = 19.6268 -
# Epoch   6: train error = 16.4747 test error = 17.7454 -
# Epoch   8: train error = 13.1323 test error = 13.3977 -
# Epoch  10: train error = 7.9861 test error = 8.0116 -
# Epoch  12: train error = 7.8587 test error = 6.7282 -
# Epoch  14: train error = 5.3640 test error = 4.9591 -
# Epoch  16: train error = 3.3829 test error = 2.7198 -
# Epoch  18: train error = 1.9550 test error = 3.8324 +
# Epoch  20: train error = 1.8735 test error = 3.6279 +
# Epoch  22: train error = 1.6942 test error = 3.0972 +
# Epoch  24: train error = 1.6193 test error = 3.4682 +
# Epoch  26: train error = 1.5759 test error = 3.1287 +
# No improvement for 5 batches. Stopping early.
# Net 0 --> test_err = 2.719801902770996
#
# Epoch   2: train error = 18.6010 test error = 18.6703 -
# Epoch   4: train error = 17.4336 test error = 16.9793 -
# Epoch   6: train error = 15.2383 test error = 13.6267 -
# Epoch   8: train error = 11.2203 test error = 8.8403 -
# Epoch  10: train error = 8.0317 test error = 4.6064 -
# Epoch  12: train error = 3.7868 test error = 3.5079 -
# Epoch  14: train error = 3.3062 test error = 3.0948 -
# Epoch  16: train error = 2.9683 test error = 3.2582 +
# Epoch  18: train error = 2.9322 test error = 2.9029 -
# Epoch  20: train error = 2.7926 test error = 2.7742 -
# Epoch  22: train error = 2.7206 test error = 2.8667 +
# Epoch  24: train error = 2.6810 test error = 2.8221 +
# Epoch  26: train error = 2.6348 test error = 2.8129 +
# Epoch  28: train error = 2.5866 test error = 2.7695 -
# Epoch  30: train error = 2.5296 test error = 2.6486 -
# Epoch  32: train error = 2.4695 test error = 2.7093 +
# Epoch  34: train error = 2.4321 test error = 2.6139 -
# Epoch  36: train error = 2.3959 test error = 2.7331 +
# Epoch  38: train error = 2.3634 test error = 2.7682 +
# Epoch  40: train error = 2.3273 test error = 2.8070 +
# Epoch  42: train error = 2.2984 test error = 2.9602 +
# Epoch  44: train error = 2.2675 test error = 2.9781 +
# No improvement for 5 batches. Stopping early.
# Net 1 --> test_err = 2.613856792449951
#
# Epoch   2: train error = 20.1866 test error = 16.0893 -
# Epoch   4: train error = 19.1482 test error = 14.7243 -
# Epoch   6: train error = 17.3809 test error = 12.2974 -
# Epoch   8: train error = 13.9291 test error = 8.1643 -
# Epoch  10: train error = 8.8422 test error = 4.7760 -
# Epoch  12: train error = 4.7641 test error = 3.2904 -
# Epoch  14: train error = 2.8654 test error = 3.1801 -
# Epoch  16: train error = 2.3147 test error = 3.1582 -
# Epoch  18: train error = 2.1069 test error = 2.8390 -
# Epoch  20: train error = 1.9592 test error = 2.7171 -
# Epoch  22: train error = 1.8501 test error = 2.6022 -
# Epoch  24: train error = 1.8036 test error = 2.5455 -
# Epoch  26: train error = 1.7383 test error = 2.5509 +
# Epoch  28: train error = 1.6787 test error = 2.5629 +
# Epoch  30: train error = 1.6108 test error = 2.5088 -
# Epoch  32: train error = 1.5472 test error = 2.6157 +
# Epoch  34: train error = 1.4828 test error = 2.6766 +
# Epoch  36: train error = 1.4503 test error = 2.6829 +
# Epoch  38: train error = 1.4099 test error = 2.7249 +
# Epoch  40: train error = 1.3856 test error = 2.6401 +
# No improvement for 5 batches. Stopping early.
# Net 2 --> test_err = 2.508802890777588
#
# Epoch   2: train error = 20.0741 test error = 19.3050 -
# Epoch   4: train error = 19.1606 test error = 17.9568 -
# Epoch   6: train error = 17.4406 test error = 15.4069 -
# Epoch   8: train error = 14.0955 test error = 11.0803 -
# Epoch  10: train error = 9.8916 test error = 6.3291 -
# Epoch  12: train error = 5.2228 test error = 2.0708 -
# Epoch  14: train error = 2.8948 test error = 1.8734 -
# Epoch  16: train error = 2.7646 test error = 1.8082 -
# Epoch  18: train error = 2.8067 test error = 1.5089 -
# Epoch  20: train error = 2.5867 test error = 1.6008 +
# Epoch  22: train error = 2.5128 test error = 1.6447 +
# Epoch  24: train error = 2.4358 test error = 1.6355 +
# Epoch  26: train error = 2.3733 test error = 1.7296 +
# Epoch  28: train error = 2.3034 test error = 1.9121 +
# No improvement for 5 batches. Stopping early.
# Net 3 --> test_err = 1.50894296169281
#
# Epoch   2: train error = 23.8449 test error = 22.7778 -
# Epoch   4: train error = 22.8938 test error = 21.7821 -
# Epoch   6: train error = 21.4130 test error = 20.1976 -
# Epoch   8: train error = 18.7746 test error = 17.1859 -
# Epoch  10: train error = 13.5571 test error = 11.3817 -
# Epoch  12: train error = 12.3368 test error = 7.0129 -
# Epoch  14: train error = 7.1878 test error = 4.8220 -
# Epoch  16: train error = 4.3759 test error = 2.3987 -
# Epoch  18: train error = 4.0170 test error = 1.9122 -
# Epoch  20: train error = 3.4998 test error = 1.7803 -
# Epoch  22: train error = 3.3448 test error = 1.8168 +
# Epoch  24: train error = 3.0083 test error = 1.5936 -
# Epoch  26: train error = 2.5992 test error = 1.5536 -
# Epoch  28: train error = 2.1167 test error = 2.1070 +
# Epoch  30: train error = 1.8551 test error = 1.7987 +
# Epoch  32: train error = 1.8638 test error = 1.7958 +
# Epoch  34: train error = 1.7510 test error = 2.0832 +
# Epoch  36: train error = 1.6867 test error = 1.9136 +
# No improvement for 5 batches. Stopping early.
# Net 4 --> test_err = 1.5535838603973389

# %%
print('chisq_XLU = {}'.format(th.chisq(mockset_XLU)))
print('chisq_XUU = {}'.format(th.chisq(mockset_XUU)))
# Out:
# chisq_XLU = (tensor(31.8807), 24, tensor(0.1300))
# chisq_XUU = (tensor(22.3991), 24, tensor(0.5555))

# %%
fig = gplots.jbod(points=mockset_XUU[:18], lines=[th], mesh=th)

# %%
fig = gplots.jbod(points=mockset_XLU[:18], lines=[th], mesh=th)

# %%
fig = gplots.CFFt(cffs=['ImH', 'ImHt'], lines=[th, th_KM15_ImHHt], mesh=th)

# %%
fig = gplots.CFFt(cffs=['ImH', 'ImHt'], lines=[th, th_KM15_ImHHt], bands=[th])

# %% [markdown]
# This is very reasonable.

# %% [markdown]
# ## Uncertainty decrease

# %%
class NN(g.model.NeuralModel, g.eff.KellyEFF, g.dvcs.BM10tw2):
    pass

# %%
tholdL2 = NN(output_layer=['ImH', 'ImHt'])
tholdL2.name = 'old-L2'
thnewL2 = NN(output_layer=['ImH', 'ImHt'])
thnewL2.name = 'new-L2'

# %%
tholdL1 = NN(output_layer=['ImH', 'ImHt'])
tholdL1.name = 'old-L1'
thnewL1 = NN(output_layer=['ImH', 'ImHt'])
thnewL1.name = 'new-L1'

# %%
dirname = 'closure/nets'
netfilename = 'c2_L2'
for k in range(1, 3):
    try:
        tholdL2.nets += torch.load('{}/{}_old-{}.tar'.format(dirname, netfilename, k))
        thnewL2.nets += torch.load('{}/{}_new-{}.tar'.format(dirname, netfilename, k))
    except:
        break
print("Loaded {} nets for {}".format(len(tholdL2.nets), tholdL2.name))
print("Loaded {} nets for {}".format(len(thnewL2.nets), thnewL2.name))
# Out:
# Loaded 0 nets for old-L2
# Loaded 0 nets for new-L2

# %%
for net, mean, std in tholdL2.nets:
    net.eval()
for net, mean, std in thnewL2.nets:
    net.eval()

# %%
dirname = 'closure/nets'
netfilename = 'c2_L1'
for k in range(1, 3):
    try:
        tholdL1.nets += torch.load('{}/{}_old-{}.tar'.format(dirname, netfilename, k))
        thnewL1.nets += torch.load('{}/{}_new-{}.tar'.format(dirname, netfilename, k))
    except:
        break
print("Loaded {} nets for {}".format(len(tholdL1.nets), tholdL1.name))
print("Loaded {} nets for {}".format(len(thnewL1.nets), thnewL1.name))
# Out:
# Loaded 0 nets for old-L1
# Loaded 0 nets for new-L1

# %%
for net, mean, std in tholdL1.nets:
    net.eval()
for net, mean, std in thnewL1.nets:
    net.eval()

# %%
fig = gplots.CFFt(cffs=['ImH', 'ImHt'], lines=[thnewL2, tholdL2, th_KM15_ImHHt], bands=[thnewL2, tholdL2])
# Out:
# /Users/higuera-admin/Documents/Programs/ldrdgff/gepard/src/gepard/theory.py:179: RuntimeWarning: Mean of empty slice.
#   result = res.mean()
# /opt/anaconda3/envs/gepard-env-NNP/lib/python3.11/site-packages/numpy/_core/_methods.py:138: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /Users/higuera-admin/Documents/Programs/ldrdgff/gepard/src/gepard/theory.py:140: RuntimeWarning: Mean of empty slice.
#   result = (res.mean(), res.std())
# /opt/anaconda3/envs/gepard-env-NNP/lib/python3.11/site-packages/numpy/_core/_methods.py:218: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/envs/gepard-env-NNP/lib/python3.11/site-packages/numpy/_core/_methods.py:175: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /opt/anaconda3/envs/gepard-env-NNP/lib/python3.11/site-packages/numpy/_core/_methods.py:210: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# # Simulation 5b - (XLU + XC) - (ImH + ReE) - (xB + t-dep)

# %% [markdown]
# ## Dataset

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(angle),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      observable='XLU')
        pt.id = 4001
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_2.predict(pt)
        pt.err = 0.1 * pt.val + 0.0002
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset_XLU = g.DataSet(mockset)

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(angle),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      observable='AC')
        pt.id = 4002
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_2.predict(pt)
        pt.err = abs(0.1 * pt.val) + 0.0002
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset_AC = g.DataSet(mockset)

# %% [markdown]
# ## Fit

# %%
class NN(g.model.NeuralModel, g.eff.KellyEFF, g.dvcs.BM10tw2):

    def build_net(self):
            '''Overriding the default architecture and optimizer'''
            nn_model = torch.nn.Sequential(
                    torch.nn.Linear(2, 23),
                    torch.nn.ReLU(),
                    torch.nn.Linear(23, 27),
                    torch.nn.ReLU(),
                    torch.nn.Linear(27, 17),
                    torch.nn.ReLU(),
                    torch.nn.Linear(17, len(self.output_layer)),
                )
            optimizer = torch.optim.Rprop(nn_model.parameters(), lr=0.01)
            return nn_model, optimizer

# %%
th = NN(output_layer=['ImH', 'ReE'])
th.name = 'NNet fit'

# %%
dirname = 'clos'
netfilename = 'imhree'
for k in range(1, 6):
    try:
        th.nets += torch.load('{}/{}-{}.tar'.format(dirname, netfilename, k))
    except:
        break
print("Loaded {} nets".format(len(th.nets)))
# Out:
# Loaded 0 nets

# %%
for net, mean, std in th.nets:
    net.eval()

# %%
f = g.fitter.NeuralFitter([mockset_XLU, mockset_AC],
                          th, nnets=5, nbatch=50, batchlen=2, regularization='L2', lx_lambda=0.001)

# %%
f = g.fitter.NeuralFitter([mockset_XLU, mockset_AC],
                          th, nnets=5, nbatch=50, batchlen=2, regularization=None, smear_replica=False)

# %%
f.fit()
# Out:
# Epoch   2: train error = 79.8048 test error = 74.6820 -
# Epoch   4: train error = 69.2599 test error = 168.8960
# Hopeless. Giving up
#
# Epoch   2: train error = 83.3111 test error = 85.6412 -
# Epoch   4: train error = 70.7446 test error = 69.2477 -
# Epoch   6: train error = 61.0536 test error = 60.4230 -
# Epoch   8: train error = 42.7545 test error = 34.5075 -
# Epoch  10: train error = 14.8431 test error = 6.0279 -
# Epoch  12: train error = 11.6030 test error = 3.1386 -
# Epoch  14: train error = 4.6349 test error = 6.9501 +
# Epoch  16: train error = 6.0333 test error = 4.7464 +
# Epoch  18: train error = 4.3539 test error = 3.3867 +
# Epoch  20: train error = 3.6577 test error = 3.3834 +
# Epoch  22: train error = 3.2053 test error = 2.8164 -
# Epoch  24: train error = 2.9109 test error = 2.9015 +
# Epoch  26: train error = 2.7326 test error = 3.2093 +
# Epoch  28: train error = 2.6651 test error = 2.7946 -
# Epoch  30: train error = 2.5488 test error = 3.0456 +
# Epoch  32: train error = 2.4419 test error = 2.9824 +
# Epoch  34: train error = 2.2880 test error = 2.9328 +
# Epoch  36: train error = 2.1142 test error = 2.6344 -
# Epoch  38: train error = 1.9959 test error = 2.8081 +
# Epoch  40: train error = 1.8728 test error = 2.9425 +
# Epoch  42: train error = 1.7715 test error = 3.2509 +
# Epoch  44: train error = 1.6965 test error = 3.5865 +
# Epoch  46: train error = 1.6220 test error = 3.6375 +
# No improvement for 5 batches. Stopping early.
# Net 0 --> test_err = 2.634404420852661
#
# Epoch   2: train error = 65.0268 test error = 65.7702 -
# Epoch   4: train error = 62.5032 test error = 63.1632 -
# Epoch   6: train error = 55.6024 test error = 54.6556 -
# Epoch   8: train error = 44.4713 test error = 35.6778 -
# Epoch  10: train error = 25.3425 test error = 9.3354 -
# Epoch  12: train error = 14.6020 test error = 2.7214 -
# Epoch  14: train error = 8.2082 test error = 3.3383 +
# Epoch  16: train error = 4.9066 test error = 3.5123 +
# Epoch  18: train error = 3.3187 test error = 5.0668 +
# Epoch  20: train error = 3.1312 test error = 6.0967 +
# Epoch  22: train error = 2.5291 test error = 5.6128 +
# No improvement for 5 batches. Stopping early.
# Net 1 --> test_err = 2.721365451812744
#
# Epoch   2: train error = 80.4900 test error = 46.5282 -
# Epoch   4: train error = 67.2764 test error = 156.0469
# Hopeless. Giving up
#
# Epoch   2: train error = 71.2984 test error = 70.3325 -
# Epoch   4: train error = 51.8821 test error = 259.0320
# Hopeless. Giving up
#
# Epoch   2: train error = 64.6784 test error = 84.5256 -
# Epoch   4: train error = 53.2313 test error = 226.8361
# Hopeless. Giving up
#
# Epoch   2: train error = 64.8914 test error = 55.5425 -
# Epoch   4: train error = 61.5697 test error = 50.7796 -
# Epoch   6: train error = 55.2428 test error = 40.7155 -
# Epoch   8: train error = 41.6547 test error = 21.6440 -
# Epoch  10: train error = 19.9699 test error = 5.7626 -
# Epoch  12: train error = 10.1564 test error = 2.8950 -
# Epoch  14: train error = 3.6620 test error = 3.8257 +
# Epoch  16: train error = 2.9631 test error = 3.6676 +
# Epoch  18: train error = 1.8310 test error = 1.7525 -
# Epoch  20: train error = 1.6099 test error = 1.7736 +
# Epoch  22: train error = 1.4063 test error = 1.9850 +
# Epoch  24: train error = 1.2415 test error = 1.6779 -
# Epoch  26: train error = 1.1020 test error = 1.6434 -
# Epoch  28: train error = 1.0249 test error = 1.6867 +
# Epoch  30: train error = 0.9738 test error = 1.7365 +
# Epoch  32: train error = 0.9062 test error = 1.8413 +
# Epoch  34: train error = 0.8615 test error = 1.8789 +
# Epoch  36: train error = 0.8062 test error = 1.8425 +
# No improvement for 5 batches. Stopping early.
# Net 2 --> test_err = 1.643375277519226
#
# Epoch   2: train error = 81.0021 test error = 77.7900 -
# Epoch   4: train error = 61.3116 test error = 67.1997 -
# Epoch   6: train error = 53.7804 test error = 61.8362 -
# Epoch   8: train error = 40.3377 test error = 38.6135 -
# Epoch  10: train error = 22.1324 test error = 15.3592 -
# Epoch  12: train error = 8.9652 test error = 9.5788 -
# Epoch  14: train error = 5.9647 test error = 5.2445 -
# Epoch  16: train error = 3.8834 test error = 3.2741 -
# Epoch  18: train error = 3.1196 test error = 2.7652 -
# Epoch  20: train error = 3.1451 test error = 3.3617 +
# Epoch  22: train error = 2.8031 test error = 2.7690 +
# Epoch  24: train error = 2.4589 test error = 2.4812 -
# Epoch  26: train error = 2.2678 test error = 2.3646 -
# Epoch  28: train error = 2.0726 test error = 2.1248 -
# Epoch  30: train error = 1.8629 test error = 2.0363 -
# Epoch  32: train error = 1.6072 test error = 2.0887 +
# Epoch  34: train error = 1.3721 test error = 2.1518 +
# Epoch  36: train error = 1.2443 test error = 2.3592 +
# Epoch  38: train error = 1.1292 test error = 2.3295 +
# Epoch  40: train error = 1.0169 test error = 2.5354 +
# No improvement for 5 batches. Stopping early.
# Net 3 --> test_err = 2.0362625122070312
#
# Epoch   2: train error = 78.2640 test error = 75.4556 -
# Epoch   4: train error = 65.3237 test error = 59.0585 -
# Epoch   6: train error = 56.1084 test error = 48.9436 -
# Epoch   8: train error = 35.7858 test error = 28.0089 -
# Epoch  10: train error = 10.4268 test error = 13.1384 -
# Epoch  12: train error = 6.3466 test error = 9.5988 -
# Epoch  14: train error = 5.6490 test error = 7.3496 -
# Epoch  16: train error = 3.6691 test error = 6.7635 -
# Epoch  18: train error = 3.0784 test error = 6.2723 -
# Epoch  20: train error = 3.6058 test error = 4.9361 -
# Epoch  22: train error = 2.5442 test error = 4.2523 -
# Epoch  24: train error = 2.3722 test error = 4.4083 +
# Epoch  26: train error = 2.2441 test error = 4.2383 -
# Epoch  28: train error = 2.1218 test error = 4.7887 +
# Epoch  30: train error = 2.0093 test error = 4.7616 +
# Epoch  32: train error = 1.9178 test error = 5.0278 +
# Epoch  34: train error = 1.8822 test error = 5.0220 +
# Epoch  36: train error = 1.7789 test error = 5.2516 +
# No improvement for 5 batches. Stopping early.
# Net 4 --> test_err = 4.238318920135498

# %%
print('chisq_XLU = {}'.format(th.chisq(mockset_XLU)))
print('chisq_XC = {}'.format(th.chisq(mockset_AC)))
# Out:
# chisq_XLU = (tensor(22.3469), 24, tensor(0.5586, dtype=torch.float64))
# chisq_XC = (tensor(28.8641), 24, tensor(0.2253, dtype=torch.float64))

# %%
fig = gplots.jbod(points=[mockset_XLU[0:6], mockset_XLU[6:12], mockset_AC[6:12], mockset_AC[12:18]], lines=[th], bands=[th])

# %%
fig.savefig('{}/XLU-AC-mesh.pdf'.format(PAPER_DIR), bbox_inches='tight', transparent=True, pad_inches=0)

# %%
fig = gplots.CFFt(cffs=['ImH', 'ReE'], lines=[th, th_KM15_2], mesh=th)

# %%
fig = gplots.CFFt(cffs=['ImH', 'ReE'], lines=[th, th_KM15_2], bands=[th])

# %%
fig.savefig('{}/ImH_ReE-band.pdf'.format(PAPER_DIR), bbox_inches='tight', transparent=True, pad_inches=0)

# %%
fig = gplots.CFF3(cffs=['ImH', 'ReE'], lines=[th, th_KM15_2], bands=[th])

# %%
fig.savefig('{}/ImH_ReE-xdata.pdf'.format(PAPER_DIR), bbox_inches='tight', transparent=True, pad_inches=0)

# %%
fig = gplots.CFF3log(cffs=['ImH', 'ReE'], lines=[th, th_KM15_2], bands=[th])

# %%
fig.savefig('{}/ImH_ReE-xlog.pdf'.format(PAPER_DIR), bbox_inches='tight', transparent=True, pad_inches=0)

# %% [markdown]
# # Simulation 6 - (XLU + XUU + ALU) - (ImH + ReE + ImHt) - (xB + t-dep)

# %% [markdown]
# ## Dataset

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(0.3),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      observable='XLU')
        pt.id = 4001
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_3.predict(pt)
        pt.err = 0.1 * pt.val + 0.0002
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset_XLU = g.DataSet(mockset)

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(0.3),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      observable='XUU')
        pt.id = 4002
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_3.predict(pt)
        pt.err = 0.1 * pt.val + 0.001
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset_XUU = g.DataSet(mockset)

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(0.3),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      observable='ALU')
        pt.id = 4003
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_3.predict(pt)
        pt.err = 0.1 * pt.val + 0.0002
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset_ALU = g.DataSet(mockset)

# %%
fig = gplots.jbod(points=mockset_ALU)

# %% [markdown]
# ## Fit

# %%
class NN(g.model.NeuralModel, g.eff.KellyEFF, g.dvcs.BM10tw2):

    def build_net(self):
            '''Overriding the default architecture and optimizer'''
            nn_model = torch.nn.Sequential(
                    torch.nn.Linear(2, 13),
                    torch.nn.ReLU(),
                    torch.nn.Linear(13, 17),
                    torch.nn.ReLU(),
                    torch.nn.Linear(17, len(self.output_layer)),
                )
            optimizer = torch.optim.Rprop(nn_model.parameters(), lr=0.01)
            return nn_model, optimizer

# %%
th = NN(output_layer=['ImH', 'ReE', 'ImHt'])
th.name = 'fit'

# %%
f = g.fitter.NeuralFitter([mockset_XLU, mockset_XUU, mockset_ALU],
                          th, nnets=5, nbatch=50, batchlen=2, regularization='L2', lx_lambda=0.001)

# %%
f.fit()
# Out:
# Epoch   2: train error = 47.4206 test error = 45.3064 -
# Epoch   4: train error = 41.2569 test error = 38.6973 -
# Epoch   6: train error = 33.5830 test error = 30.6732 -
# Epoch   8: train error = 24.4299 test error = 20.4011 -
# Epoch  10: train error = 18.7307 test error = 14.7441 -
# Epoch  12: train error = 14.6315 test error = 11.0653 -
# Epoch  14: train error = 9.5528 test error = 5.3941 -
# Epoch  16: train error = 4.8175 test error = 3.2304 -
# Epoch  18: train error = 2.6161 test error = 3.0968 -
# Epoch  20: train error = 2.2169 test error = 2.4768 -
# Epoch  22: train error = 2.2034 test error = 2.8912 +
# Epoch  24: train error = 2.1687 test error = 2.6283 +
# Epoch  26: train error = 2.1146 test error = 2.6953 +
# Epoch  28: train error = 2.0995 test error = 2.6160 +
# Epoch  30: train error = 2.0673 test error = 2.6744 +
# No improvement for 5 batches. Stopping early.
# Net 0 --> test_err = 2.4767746925354004
#
# Epoch   2: train error = 48.5046 test error = 41.9379 -
# Epoch   4: train error = 40.3928 test error = 33.4822 -
# Epoch   6: train error = 29.3642 test error = 23.1590 -
# Epoch   8: train error = 17.0132 test error = 12.6054 -
# Epoch  10: train error = 10.2249 test error = 7.8256 -
# Epoch  12: train error = 5.4765 test error = 3.2734 -
# Epoch  14: train error = 2.8959 test error = 1.6161 -
# Epoch  16: train error = 2.6628 test error = 1.7548 +
# Epoch  18: train error = 2.6179 test error = 2.0414 +
# Epoch  20: train error = 2.3024 test error = 1.6850 +
# Epoch  22: train error = 2.2697 test error = 1.7017 +
# Epoch  24: train error = 2.2044 test error = 1.7010 +
# No improvement for 5 batches. Stopping early.
# Net 1 --> test_err = 1.6160639524459839
#
# Epoch   2: train error = 51.6698 test error = 41.2246 -
# Epoch   4: train error = 44.2272 test error = 34.9211 -
# Epoch   6: train error = 33.9543 test error = 25.8668 -
# Epoch   8: train error = 21.5299 test error = 14.1180 -
# Epoch  10: train error = 7.8968 test error = 5.3464 -
# Epoch  12: train error = 4.5657 test error = 4.3639 -
# Epoch  14: train error = 2.1598 test error = 2.6812 -
# Epoch  16: train error = 1.9835 test error = 2.6504 -
# Epoch  18: train error = 1.8519 test error = 2.4362 -
# Epoch  20: train error = 1.7816 test error = 2.3353 -
# Epoch  22: train error = 1.7278 test error = 2.2246 -
# Epoch  24: train error = 1.6640 test error = 2.1197 -
# Epoch  26: train error = 1.6109 test error = 2.0624 -
# Epoch  28: train error = 1.5675 test error = 1.9645 -
# Epoch  30: train error = 1.5259 test error = 1.8943 -
# Epoch  32: train error = 1.4802 test error = 1.8415 -
# Epoch  34: train error = 1.4433 test error = 1.8629 +
# Epoch  36: train error = 1.4103 test error = 1.8414 -
# Epoch  38: train error = 1.3774 test error = 1.8613 +
# Epoch  40: train error = 1.3496 test error = 1.8535 +
# Epoch  42: train error = 1.3301 test error = 1.8213 -
# Epoch  44: train error = 1.3118 test error = 1.8494 +
# Epoch  46: train error = 1.2978 test error = 1.8291 +
# Epoch  48: train error = 1.2849 test error = 1.8013 -
# Epoch  50: train error = 1.2733 test error = 1.8408 +
# Epoch  52: train error = 1.2621 test error = 1.8544 +
# Epoch  54: train error = 1.2538 test error = 1.8470 +
# Epoch  56: train error = 1.2478 test error = 1.8514 +
# Epoch  58: train error = 1.2399 test error = 1.8628 +
# No improvement for 5 batches. Stopping early.
# Net 2 --> test_err = 1.8013341426849365
#
# Epoch   2: train error = 49.6331 test error = 50.2842 -
# Epoch   4: train error = 44.3764 test error = 44.1580 -
# Epoch   6: train error = 37.5641 test error = 35.9999 -
# Epoch   8: train error = 28.8303 test error = 24.0272 -
# Epoch  10: train error = 18.1495 test error = 15.5987 -
# Epoch  12: train error = 11.3552 test error = 11.2337 -
# Epoch  14: train error = 4.6446 test error = 3.5522 -
# Epoch  16: train error = 2.5092 test error = 2.9641 -
# Epoch  18: train error = 2.3461 test error = 2.7555 -
# Epoch  20: train error = 2.1111 test error = 2.7361 -
# Epoch  22: train error = 2.0119 test error = 2.6758 -
# Epoch  24: train error = 1.9794 test error = 2.6021 -
# Epoch  26: train error = 1.9591 test error = 2.5404 -
# Epoch  28: train error = 1.9227 test error = 2.6084 +
# Epoch  30: train error = 1.8853 test error = 2.5760 +
# Epoch  32: train error = 1.8462 test error = 2.5924 +
# Epoch  34: train error = 1.7991 test error = 2.6626 +
# Epoch  36: train error = 1.7545 test error = 2.6814 +
# No improvement for 5 batches. Stopping early.
# Net 3 --> test_err = 2.5404176712036133
#
# Epoch   2: train error = 51.4240 test error = 40.2272 -
# Epoch   4: train error = 41.8529 test error = 34.8661 -
# Epoch   6: train error = 30.9123 test error = 27.4131 -
# Epoch   8: train error = 18.9917 test error = 16.5383 -
# Epoch  10: train error = 9.6745 test error = 7.6019 -
# Epoch  12: train error = 5.4006 test error = 4.3171 -
# Epoch  14: train error = 2.7468 test error = 3.2308 -
# Epoch  16: train error = 2.3366 test error = 3.1011 -
# Epoch  18: train error = 1.8183 test error = 2.8211 -
# Epoch  20: train error = 1.6697 test error = 2.7877 -
# Epoch  22: train error = 1.6111 test error = 2.6011 -
# Epoch  24: train error = 1.5395 test error = 2.5503 -
# Epoch  26: train error = 1.4908 test error = 2.4780 -
# Epoch  28: train error = 1.4363 test error = 2.4470 -
# Epoch  30: train error = 1.3817 test error = 2.4256 -
# Epoch  32: train error = 1.3318 test error = 2.4264 +
# Epoch  34: train error = 1.2939 test error = 2.4286 +
# Epoch  36: train error = 1.2616 test error = 2.4432 +
# Epoch  38: train error = 1.2337 test error = 2.4213 -
# Epoch  40: train error = 1.2095 test error = 2.4353 +
# Epoch  42: train error = 1.1913 test error = 2.4549 +
# Epoch  44: train error = 1.1755 test error = 2.4649 +
# Epoch  46: train error = 1.1643 test error = 2.4546 +
# Epoch  48: train error = 1.1525 test error = 2.4477 +
# No improvement for 5 batches. Stopping early.
# Net 4 --> test_err = 2.421339988708496

# %%
print('chisq_XLU = {}'.format(th.chisq(mockset_XLU)))
print('chisq_XUU = {}'.format(th.chisq(mockset_XUU)))
print('chisq_ALU = {}'.format(th.chisq(mockset_ALU)))
# Out:
# chisq_XLU = (tensor(95.3680), 120, tensor(0.9526, dtype=torch.float64))
# chisq_XUU = (tensor(20.1912), 24, tensor(0.6859, dtype=torch.float64))
# chisq_ALU = (tensor(12.9276), 24, tensor(0.9673, dtype=torch.float64))

# %%
fig = gplots.jbod(points=mockset_XUU[:18], lines=[th], mesh=th)

# %%
fig = gplots.jbod(points=mockset_XLU[:18], lines=[th], mesh=th)

# %%
fig = gplots.jbod(points=mockset_ALU[:18], lines=[th], mesh=th)

# %%
fig = gplots.CFFt(cffs=['ImH', 'ReE', 'ImHt'], lines=[th, th_KM15_3], mesh=th)

# %%
fig = gplots.CFFt(cffs=['ImH', 'ReE', 'ImHt'], lines=[th, th_KM15_3], bands=[th])

# %% [markdown]
# Still not so bad. Sensitivity of ReE is weak - not surprising since only XUU has some weak contribution.

# %% [markdown]
# # Simulation 7 - (XLU + XUU + ALU + AC) - (ImH + ReH + ReE + ImHt) - (xB + t-dep)

# %% [markdown]
# ## Dataset

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(0.3),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      observable='XLU')
        pt.id = 4001
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_4.predict(pt)
        pt.err = 0.1 * pt.val + 0.0002
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset_XLU = g.DataSet(mockset)

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(0.3),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      observable='XUU')
        pt.id = 4002
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_4.predict(pt)
        pt.err = 0.1 * pt.val + 0.001
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset_XUU = g.DataSet(mockset)

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(0.3),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      observable='ALU')
        pt.id = 4003
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_4.predict(pt)
        pt.err = 0.1 * pt.val + 0.0002
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset_ALU = g.DataSet(mockset)

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(0.3),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      observable='AC')
        pt.id = 4004
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_4.predict(pt)
        pt.err = 0.1 * pt.val + 0.0002
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset_AC = g.DataSet(mockset)

# %%
fig = gplots.jbod(points=mockset_AC)

# %%
len(mockset_XLU),  len(mockset_XUU),  len(mockset_ALU),  len(mockset_AC)
# Out:
# (24, 24, 24, 24)

# %% [markdown]
# ## Fit

# %%
class NN(g.model.NeuralModel, g.eff.KellyEFF, g.dvcs.BM10tw2):

    def build_net(self):
            '''Overriding the default architecture and optimizer'''
            nn_model = torch.nn.Sequential(
                    torch.nn.Linear(2, 13),
                    torch.nn.ReLU(),
                    torch.nn.Linear(13, 27),
                    torch.nn.ReLU(),
                    torch.nn.Linear(27, 17),
                    torch.nn.ReLU(),
                    torch.nn.Linear(17, len(self.output_layer)),
                )
            optimizer = torch.optim.Rprop(nn_model.parameters(), lr=0.01)
            return nn_model, optimizer

# %%
th = NN(output_layer=['ImH', 'ReH', 'ReE', 'ImHt'])
th.name = 'fit'

# %%
f = g.fitter.NeuralFitter([mockset_XLU, mockset_XUU, mockset_ALU, mockset_AC],
                          th, nnets=5, nbatch=50, batchlen=2, regularization='L2', lx_lambda=0.001)

# %%
f.fit()
# Out:
# Epoch   2: train error = 81.5418 test error = 77.4800 -
# Epoch   4: train error = 63.7890 test error = 58.2329 -
# Epoch   6: train error = 47.2293 test error = 39.4317 -
# Epoch   8: train error = 27.6893 test error = 20.9178 -
# Epoch  10: train error = 9.6519 test error = 12.4617 -
# Epoch  12: train error = 5.6767 test error = 6.8741 -
# Epoch  14: train error = 4.4859 test error = 4.7735 -
# Epoch  16: train error = 4.1704 test error = 4.8910 +
# Epoch  18: train error = 3.5714 test error = 4.0375 -
# Epoch  20: train error = 3.1118 test error = 3.7927 -
# Epoch  22: train error = 2.5124 test error = 2.9424 -
# Epoch  24: train error = 2.2870 test error = 2.7918 -
# Epoch  26: train error = 2.0785 test error = 3.2974 +
# Epoch  28: train error = 1.9245 test error = 2.9919 +
# Epoch  30: train error = 1.7633 test error = 3.3222 +
# Epoch  32: train error = 1.6800 test error = 3.2082 +
# Epoch  34: train error = 1.5599 test error = 3.3683 +
# No improvement for 5 batches. Stopping early.
# Net 0 --> test_err = 2.791762113571167
#
# Epoch   2: train error = 51.8405 test error = 50.1060 -
# Epoch   4: train error = 43.8953 test error = 36.7981 -
# Epoch   6: train error = 31.6173 test error = 17.6600 -
# Epoch   8: train error = 14.0936 test error = 21.8647 +
# Epoch  10: train error = 13.0558 test error = 6.7225 -
# Epoch  12: train error = 7.5216 test error = 3.8269 -
# Epoch  14: train error = 4.6484 test error = 3.5109 -
# Epoch  16: train error = 3.1069 test error = 4.3372 +
# Epoch  18: train error = 2.2805 test error = 3.0455 -
# Epoch  20: train error = 1.8351 test error = 3.3536 +
# Epoch  22: train error = 1.6452 test error = 3.0042 -
# Epoch  24: train error = 1.5622 test error = 3.0146 +
# Epoch  26: train error = 1.4625 test error = 3.3415 +
# Epoch  28: train error = 1.3862 test error = 3.3517 +
# Epoch  30: train error = 1.3204 test error = 3.5346 +
# Epoch  32: train error = 1.2540 test error = 3.7596 +
# No improvement for 5 batches. Stopping early.
# Net 1 --> test_err = 3.004230499267578
#
# Epoch   2: train error = 47.1722 test error = 42.9655 -
# Epoch   4: train error = 36.7981 test error = 27.3038 -
# Epoch   6: train error = 19.8325 test error = 10.1852 -
# Epoch   8: train error = 8.1014 test error = 5.3328 -
# Epoch  10: train error = 4.0127 test error = 6.6651 +
# Epoch  12: train error = 3.8289 test error = 4.4180 -
# Epoch  14: train error = 3.3854 test error = 3.4658 -
# Epoch  16: train error = 2.9060 test error = 4.0106 +
# Epoch  18: train error = 2.6397 test error = 3.4921 +
# Epoch  20: train error = 2.4818 test error = 3.7377 +
# Epoch  22: train error = 2.3032 test error = 3.2129 -
# Epoch  24: train error = 2.1667 test error = 3.4909 +
# Epoch  26: train error = 2.0642 test error = 3.0801 -
# Epoch  28: train error = 1.9821 test error = 2.9656 -
# Epoch  30: train error = 1.9183 test error = 2.9963 +
# Epoch  32: train error = 1.8577 test error = 3.1379 +
# Epoch  34: train error = 1.7850 test error = 3.2277 +
# Epoch  36: train error = 1.7245 test error = 3.2957 +
# Epoch  38: train error = 1.6574 test error = 3.5905 +
# No improvement for 5 batches. Stopping early.
# Net 2 --> test_err = 2.9656431674957275
#
# Epoch   2: train error = 60.0134 test error = 55.9563 -
# Epoch   4: train error = 49.0005 test error = 43.5511 -
# Epoch   6: train error = 37.6792 test error = 25.9902 -
# Epoch   8: train error = 21.3036 test error = 15.7429 -
# Epoch  10: train error = 14.3576 test error = 6.8508 -
# Epoch  12: train error = 5.2250 test error = 2.7978 -
# Epoch  14: train error = 3.8953 test error = 4.1566 +
# Epoch  16: train error = 3.0420 test error = 3.2525 +
# Epoch  18: train error = 2.4006 test error = 3.1147 +
# Epoch  20: train error = 1.8996 test error = 4.3435 +
# Epoch  22: train error = 1.7489 test error = 3.3214 +
# No improvement for 5 batches. Stopping early.
# Net 3 --> test_err = 2.797813892364502
#
# Epoch   2: train error = 58.4213 test error = 60.0183 -
# Epoch   4: train error = 48.6971 test error = 48.1207 -
# Epoch   6: train error = 36.5504 test error = 32.0666 -
# Epoch   8: train error = 19.2498 test error = 12.6886 -
# Epoch  10: train error = 8.8020 test error = 6.2089 -
# Epoch  12: train error = 5.7249 test error = 4.8203 -
# Epoch  14: train error = 4.3059 test error = 3.3190 -
# Epoch  16: train error = 3.5052 test error = 2.5774 -
# Epoch  18: train error = 2.6225 test error = 2.3458 -
# Epoch  20: train error = 2.0889 test error = 2.2535 -
# Epoch  22: train error = 1.9697 test error = 2.1782 -
# Epoch  24: train error = 1.9356 test error = 2.1657 -
# Epoch  26: train error = 1.8515 test error = 2.2255 +
# Epoch  28: train error = 1.7555 test error = 2.3649 +
# Epoch  30: train error = 1.6862 test error = 2.3882 +
# Epoch  32: train error = 1.6289 test error = 2.2742 +
# Epoch  34: train error = 1.5795 test error = 2.3036 +
# No improvement for 5 batches. Stopping early.
# Net 4 --> test_err = 2.1656603813171387

# %%
torch.save(th.nets, 'one.tar')

# %%
print('chisq_XLU = {}'.format(th.chisq(mockset_XLU)))
print('chisq_XUU = {}'.format(th.chisq(mockset_XUU)))
print('chisq_ALU = {}'.format(th.chisq(mockset_ALU)))
print('chisq_AC = {}'.format(th.chisq(mockset_AC)))
# Out:
# chisq_XLU = (tensor(29.0409), 24, tensor(0.2186, dtype=torch.float64))
# chisq_XUU = (tensor(16.0198), 24, tensor(0.8874, dtype=torch.float64))
# chisq_ALU = (tensor(30.8033), 24, tensor(0.1595, dtype=torch.float64))
# chisq_AC = (tensor(22.0342), 24, tensor(0.5772, dtype=torch.float64))

# %%
fig = gplots.jbod(points=mockset_XUU[:18], lines=[th], mesh=th)

# %%
fig = gplots.jbod(points=mockset_XLU[:18], lines=[th], mesh=th)

# %%
fig = gplots.jbod(points=mockset_ALU[:18], lines=[th], mesh=th)

# %%
fig = gplots.jbod(points=mockset_AC[:18], lines=[th], mesh=th)

# %%
fig = gplots.CFFt(cffs=['ImH', 'ReH', 'ReE', 'ImHt'], lines=[th, th_KM15_4], mesh=th)

# %%
fig = gplots.CFFt(cffs=['ImH', 'ReH', 'ReE', 'ImHt'], lines=[th, th_KM15_4], bands=[th])

# %% [markdown]
# # Simulation 8 - (XLU + XUU + ALU + AC + AUT,DVCS) - (ImH + ReH + ReE + ImHt) - (xB + t-dep)

# %% [markdown]
# ## Dataset

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(angle),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      observable='XLU')
        pt.id = 4001
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_4.predict(pt)
        pt.err = 0.1 * pt.val + 0.002
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset_XLU = g.DataSet(mockset)

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(angle),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      observable='XUU')
        pt.id = 4002
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_4.predict(pt)
        pt.err = 0.1 * pt.val + 0.002
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset_XUU = g.DataSet(mockset)

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(angle),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      in2polarizationvector='L', in2polarization=+1,
                      observable='XUL')
        pt.id = 4003
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_4.predict(pt)
        pt.err = 0.1 * pt.val + 0.002
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset_XUL = g.DataSet(mockset)

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(angle),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      observable='AC')
        pt.id = 4004
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_4.predict(pt)
        pt.err = 0.1 * pt.val + 0.002
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset_AC = g.DataSet(mockset)

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(angle),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      in2polarizationvector='T', in2polarization=+1, varphi=torch.tensor(0.3),
                      observable='AUTDVCS')
        pt.id = 4005
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_4.predict(pt)
        pt.err = abs(0.1 * pt.val) + 0.002
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset_AUTDVCS = g.DataSet(mockset)

# %%
len(mockset_XLU),  len(mockset_XUU),  len(mockset_XUL),  len(mockset_AC),  len(mockset_AUTDVCS)
# Out:
# (24, 24, 24, 24, 24)

# %% [markdown]
# ## Fit

# %%
class NN(g.model.NeuralModel, g.eff.KellyEFF, g.dvcs.BM10tw2):

    def build_net(self):
            '''Overriding the default architecture and optimizer'''
            nn_model = torch.nn.Sequential(
                    torch.nn.Linear(2, 23),
                    torch.nn.ReLU(),
                    torch.nn.Linear(23, 37),
                    torch.nn.ReLU(),
                    torch.nn.Linear(37, 27),
                    torch.nn.ReLU(),
                    torch.nn.Linear(27, len(self.output_layer)),
                )
            optimizer = torch.optim.Rprop(nn_model.parameters(), lr=0.01)
            return nn_model, optimizer

# %%
th = NN(output_layer=['ImH', 'ReH', 'ReE', 'ImHt'])
th.name = 'fit'

# %%
dirname = 'clos'
netfilename = 'cff4'
for k in range(1, 6):
    try:
        th.nets += torch.load('{}/{}-{}.tar'.format(dirname, netfilename, k))
    except:
        break
print("Loaded {} nets".format(len(th.nets)))
# Out:
# Loaded 20 nets

# %%
f = g.fitter.NeuralFitter([mockset_XLU, mockset_XUU, mockset_XUL, mockset_AC, mockset_AUTDVCS],
                          th, nnets=3, nbatch=50, batchlen=2, regularization='L2', lx_lambda=0.001)

# %%
f.fit()
# Out:
# Epoch   2: train error = 24.4076 test error = 25.3406 -
# Epoch   4: train error = 15.9762 test error = 16.2080 -
# Epoch   6: train error = 9.7878 test error = 5.8470 -
# Epoch   8: train error = 7.0874 test error = 4.7380 -
# Epoch  10: train error = 4.8661 test error = 3.1658 -
# Epoch  12: train error = 2.7718 test error = 2.2919 -
# Epoch  14: train error = 2.2233 test error = 2.1747 -
# Epoch  16: train error = 1.7586 test error = 2.0184 -
# Epoch  18: train error = 1.5191 test error = 2.1628 +
# Epoch  20: train error = 1.3681 test error = 1.8847 -
# Epoch  22: train error = 1.2873 test error = 2.0788 +
# Epoch  24: train error = 1.2230 test error = 1.9598 +
# Epoch  26: train error = 1.1766 test error = 2.1092 +
# Epoch  28: train error = 1.1341 test error = 2.1952 +
# Epoch  30: train error = 1.0939 test error = 2.1943 +
# No improvement for 5 batches. Stopping early.
# Net 0 --> test_err = 1.8847392797470093
#
# Epoch   2: train error = 25.2514 test error = 19.6254 -
# Epoch   4: train error = 17.7480 test error = 11.3281 -
# Epoch   6: train error = 11.1686 test error = 7.0139 -
# Epoch   8: train error = 7.2712 test error = 6.7358 -
# Epoch  10: train error = 6.1258 test error = 6.3112 -
# Epoch  12: train error = 4.1537 test error = 3.6654 -
# Epoch  14: train error = 3.2743 test error = 2.7316 -
# Epoch  16: train error = 2.3176 test error = 3.1210 +
# Epoch  18: train error = 1.8915 test error = 2.6619 -
# Epoch  20: train error = 1.6383 test error = 2.5907 -
# Epoch  22: train error = 1.5192 test error = 2.6648 +
# Epoch  24: train error = 1.4590 test error = 2.5983 +
# Epoch  26: train error = 1.4046 test error = 2.5594 -
# Epoch  28: train error = 1.3459 test error = 2.5335 -
# Epoch  30: train error = 1.2951 test error = 2.4674 -
# Epoch  32: train error = 1.2514 test error = 2.5007 +
# Epoch  34: train error = 1.2145 test error = 2.4780 +
# Epoch  36: train error = 1.1788 test error = 2.5473 +
# Epoch  38: train error = 1.1459 test error = 2.5267 +
# Epoch  40: train error = 1.1183 test error = 2.5284 +
# No improvement for 5 batches. Stopping early.
# Net 1 --> test_err = 2.467449903488159
#
# Epoch   2: train error = 25.6058 test error = 19.8446 -
# Epoch   4: train error = 21.1359 test error = 13.6319 -
# Epoch   6: train error = 14.4471 test error = 5.9724 -
# Epoch   8: train error = 8.3789 test error = 5.7781 -
# Epoch  10: train error = 6.5412 test error = 5.0006 -
# Epoch  12: train error = 5.2405 test error = 4.8696 -
# Epoch  14: train error = 3.2143 test error = 4.4691 -
# Epoch  16: train error = 3.1305 test error = 4.2613 -
# Epoch  18: train error = 2.5653 test error = 3.8629 -
# Epoch  20: train error = 2.4034 test error = 3.6479 -
# Epoch  22: train error = 2.2954 test error = 3.4995 -
# Epoch  24: train error = 2.1551 test error = 3.5026 +
# Epoch  26: train error = 2.0083 test error = 3.7300 +
# Epoch  28: train error = 1.8834 test error = 3.7228 +
# Epoch  30: train error = 1.7824 test error = 3.6807 +
# Epoch  32: train error = 1.6945 test error = 3.6287 +
# No improvement for 5 batches. Stopping early.
# Net 2 --> test_err = 3.499476909637451

# %%
print('chisq_XLU = {}'.format(th.chisq(mockset_XLU)))
print('chisq_XUU = {}'.format(th.chisq(mockset_XUL)))
print('chisq_XUL = {}'.format(th.chisq(mockset_XUL)))
print('chisq_AC = {}'.format(th.chisq(mockset_AC)))
print('chisq_AUTDVCS = {}'.format(th.chisq(mockset_AUTDVCS)))
# Out:
# chisq_XLU = (tensor(28.8406), 24, tensor(0.2262, dtype=torch.float64))
# chisq_XUU = (tensor(13.9187), 24, tensor(0.9485, dtype=torch.float64))
# chisq_XUL = (tensor(13.9187), 24, tensor(0.9485, dtype=torch.float64))
# chisq_AC = (tensor(23.9992), 24, tensor(0.4616, dtype=torch.float64))
# chisq_AUTDVCS = (tensor(13.7438), 24, tensor(0.9522, dtype=torch.float64))

# %%
fig = gplots.jbod(points=mockset_XUU[:18], lines=[th], mesh=th)

# %%
fig = gplots.jbod(points=mockset_XLU[:18], lines=[th], mesh=th)

# %%
fig = gplots.jbod(points=mockset_XUL[:18], lines=[th], mesh=th)

# %%
fig = gplots.jbod(points=mockset_AC[:18], lines=[th], mesh=th)

# %%
fig = gplots.jbod(points=mockset_AUTDVCS[:18], lines=[th], mesh=th)

# %%
fig = gplots.CFFt(cffs=['ImH', 'ReH', 'ReE', 'ImHt'], lines=[th, th_KM15_4], mesh=th)

# %%
fig = gplots.CFFt(cffs=['ImH', 'ReH', 'ReE', 'ImHt'], lines=[th, th_KM15_4], bands=[th])

# %% [markdown]
# # Simulation 9 - (XLU + XUU + ALU + AC + AUT,DVCS) - (ImH + ReH + ImE + ReE + ImHt) - (xB + t-dep)

# %% [markdown]
# ## Dataset

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(angle),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      observable='XLU')
        pt.id = 4001
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_5.predict(pt)
        pt.err = 0.1 * pt.val + 0.002
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset_XLU = g.DataSet(mockset)

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(angle),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      observable='XUU')
        pt.id = 4002
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_5.predict(pt)
        pt.err = 0.1 * pt.val + 0.002
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset_XUU = g.DataSet(mockset)

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(angle),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      in2polarizationvector='L', in2polarization=+1,
                      observable='XUL')
        pt.id = 4003
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_5.predict(pt)
        pt.err = 0.1 * pt.val + 0.002
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset_XUL = g.DataSet(mockset)

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(angle),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      observable='AC')
        pt.id = 4004
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_5.predict(pt)
        pt.err = 0.1 * pt.val + 0.002
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset_AC = g.DataSet(mockset)

# %%
mockset = []
for xB in np.linspace(0.1, 0.25, 4):
    for tm in np.linspace(0.1, 0.5, 6):
        pt = g.DataPoint(xB=xB, t=-tm, Q2=torch.tensor(2.), phi=torch.tensor(angle),
                      process='ep2epgamma', exptype='fixed target', frame='Trento',
                      in1energy=12., in1charge=-1, in1polarization=+1,
                      in2polarizationvector='T', in2polarization=+1, varphi=torch.tensor(0.3),
                      observable='AUTDVCS')
        pt.id = 4005
        pt.year = 2023
        pt.collaboration = 'mock'
        pt.reference = 'mock'
        pt.val = th_KM15_5.predict(pt)
        pt.err = abs(0.1 * pt.val) + 0.002
        pt.val = pt.val + np.random.normal(0, pt.err, 1)[0]  # noise
        mockset.append(pt)
mockset_AUTDVCS = g.DataSet(mockset)

# %%
len(mockset_XLU),  len(mockset_XUU),  len(mockset_XUL),  len(mockset_AC),  len(mockset_AUTDVCS)
# Out:
# (24, 24, 24, 24, 24)

# %% [markdown]
# ## Fit

# %%
class NN(g.model.NeuralModel, g.eff.KellyEFF, g.dvcs.BM10tw2):

    def build_net(self):
            '''Overriding the default architecture and optimizer'''
            nn_model = torch.nn.Sequential(
                    torch.nn.Linear(2, 23),
                    torch.nn.ReLU(),
                    torch.nn.Linear(23, 37),
                    torch.nn.ReLU(),
                    torch.nn.Linear(37, 27),
                    torch.nn.ReLU(),
                    torch.nn.Linear(27, len(self.output_layer)),
                )
            optimizer = torch.optim.Rprop(nn_model.parameters(), lr=0.01)
            return nn_model, optimizer

# %%
th = NN(output_layer=['ImH', 'ReH', 'ImE', 'ReE', 'ImHt'])
th.name = 'fit'

# %%
dirname = 'clos'
netfilename = 'cff5'
for k in range(1, 6):
    try:
        th.nets += torch.load('{}/{}-{}.tar'.format(dirname, netfilename, k))
    except:
        break
print("Loaded {} nets".format(len(th.nets)))
# Out:
# Loaded 0 nets

# %%
for net, mean, std in th.nets:
    net.eval()

# %%
f = g.fitter.NeuralFitter([mockset_XLU, mockset_XUU, mockset_XUL, mockset_AC, mockset_AUTDVCS],
                          th, nnets=3, nbatch=50, batchlen=2, regularization='L2', lx_lambda=0.001)

# %%
f.fit()
# Out:
# Epoch   2: train error = 35.3876 test error = 33.9596 -
# Epoch   4: train error = 27.5133 test error = 23.2208 -
# Epoch   6: train error = 12.7857 test error = 9.6111 -
# Epoch   8: train error = 6.4099 test error = 6.6041 -
# Epoch  10: train error = 4.4843 test error = 4.6794 -
# Epoch  12: train error = 3.5877 test error = 3.2468 -
# Epoch  14: train error = 2.8961 test error = 3.6947 +
# Epoch  16: train error = 2.5933 test error = 2.8438 -
# Epoch  18: train error = 2.4592 test error = 2.8396 -
# Epoch  20: train error = 2.3486 test error = 2.5436 -
# Epoch  22: train error = 2.2150 test error = 2.4464 -
# Epoch  24: train error = 2.1005 test error = 2.3970 -
# Epoch  26: train error = 2.0222 test error = 2.4592 +
# Epoch  28: train error = 1.9568 test error = 2.4802 +
# Epoch  30: train error = 1.8957 test error = 2.6290 +
# Epoch  32: train error = 1.8343 test error = 2.7633 +
# Epoch  34: train error = 1.7820 test error = 2.7887 +
# No improvement for 5 batches. Stopping early.
# Net 0 --> test_err = 2.3970208168029785
#
# Epoch   2: train error = 28.8958 test error = 18.2626 -
# Epoch   4: train error = 18.9508 test error = 6.1150 -
# Epoch   6: train error = 8.0272 test error = 10.6878 +
# Epoch   8: train error = 5.3158 test error = 4.0188 -
# Epoch  10: train error = 3.6203 test error = 4.0604 +
# Epoch  12: train error = 2.5278 test error = 3.2356 -
# Epoch  14: train error = 2.0477 test error = 2.8455 -
# Epoch  16: train error = 1.8634 test error = 3.1878 +
# Epoch  18: train error = 1.6819 test error = 2.8083 -
# Epoch  20: train error = 1.5774 test error = 2.6484 -
# Epoch  22: train error = 1.5214 test error = 2.8418 +
# Epoch  24: train error = 1.4652 test error = 2.9349 +
# Epoch  26: train error = 1.4211 test error = 2.9534 +
# Epoch  28: train error = 1.3890 test error = 2.9823 +
# Epoch  30: train error = 1.3710 test error = 2.9569 +
# No improvement for 5 batches. Stopping early.
# Net 1 --> test_err = 2.6484389305114746
#
# Epoch   2: train error = 24.4528 test error = 35.2439 -
# Epoch   4: train error = 17.8959 test error = 25.5944 -
# Epoch   6: train error = 8.9445 test error = 8.7485 -
# Epoch   8: train error = 5.1566 test error = 4.6968 -
# Epoch  10: train error = 2.6896 test error = 3.8548 -
# Epoch  12: train error = 2.1813 test error = 2.9460 -
# Epoch  14: train error = 1.6789 test error = 3.8288 +
# Epoch  16: train error = 1.4933 test error = 2.9526 +
# Epoch  18: train error = 1.3378 test error = 3.2487 +
# Epoch  20: train error = 1.2051 test error = 2.9776 +
# Epoch  22: train error = 1.0778 test error = 2.8972 -
# Epoch  24: train error = 0.9389 test error = 3.0196 +
# Epoch  26: train error = 0.8502 test error = 2.9394 +
# Epoch  28: train error = 0.8087 test error = 3.1525 +
# Epoch  30: train error = 0.7765 test error = 3.8397 +
# Epoch  32: train error = 0.7387 test error = 3.4135 +
# No improvement for 5 batches. Stopping early.
# Net 2 --> test_err = 2.897155284881592

# %%
print('chisq_XLU = {}'.format(th.chisq(mockset_XLU)))
print('chisq_XUU = {}'.format(th.chisq(mockset_XUL)))
print('chisq_XUL = {}'.format(th.chisq(mockset_XUL)))
print('chisq_AC = {}'.format(th.chisq(mockset_AC)))
print('chisq_AUTDVCS = {}'.format(th.chisq(mockset_AUTDVCS)))
# Out:
# chisq_XLU = (tensor(26.9137), 24, tensor(0.3085, dtype=torch.float64))
# chisq_XUU = (tensor(19.5918), 24, tensor(0.7197, dtype=torch.float64))
# chisq_XUL = (tensor(19.5918), 24, tensor(0.7197, dtype=torch.float64))
# chisq_AC = (tensor(18.2949), 24, tensor(0.7885, dtype=torch.float64))
# chisq_AUTDVCS = (tensor(22.6444), 24, tensor(0.5409, dtype=torch.float64))

# %%
fig = gplots.jbod(points=[mockset_AC[:6], mockset_AC[6:12], mockset_XLU[:6], mockset_AUTDVCS[12:18]], lines=[th], bands=[th])

# %%
fig.savefig('{}/five-mesh.pdf'.format(PAPER_DIR), bbox_inches='tight', transparent=True, pad_inches=0)

# %%
fig = gplots.CFFt(cffs=['ImH', 'ReH', 'ImE', 'ReE', 'ImHt'], lines=[th, th_KM15_5], mesh=th)

# %%
fig = gplots.CFFt(cffs=['ImH', 'ReH', 'ImE', 'ReE', 'ImHt'], lines=[th, th_KM15_5], bands=[th])

# %%
fig.savefig('{}/five-tdep.pdf'.format(PAPER_DIR), bbox_inches='tight', transparent=True, pad_inches=0)

# %%
fig = gplots.CFF3(cffs=['ImH', 'ReH', 'ImE', 'ReE', 'ImHt', 'ImHt'], lines=[th, th_KM15_5], bands=[th])

# %%
fig = gplots.CFF3log(cffs=['ImH', 'ReH', 'ImE', 'ReE', 'ImHt', 'ImHt'], lines=[th, th_KM15_5], bands=[th])

# %%
fig.savefig('{}five-xdep.pdf'.format(PAPER_DIR), bbox_inches='tight', transparent=True, pad_inches=0)

# %% [markdown]
# # Simulation 10 - investigating shrinking of uncertainties

# %%
class NN(g.model.NeuralModel, g.eff.KellyEFF, g.dvcs.BM10tw2):
    pass

# %%
thold = NN(output_layer=['ImH', 'ReH', 'ReE', 'ImHt'])
thold.name = 'old'
thnew = NN(output_layer=['ImH', 'ReH', 'ReE', 'ImHt'])
thnew.name = 'new'

# %%
tholdL25 = NN(output_layer=['ImH', 'ReH', 'ReE', 'ImHt'])
tholdL25.name = 'old-L25'
thnewL25 = NN(output_layer=['ImH', 'ReH', 'ReE', 'ImHt'])
thnewL25.name = 'new-L25'

# %%
tholdL1 = NN(output_layer=['ImH', 'ReH', 'ReE', 'ImHt'])
tholdL1.name = 'old-L1'
thnewL1 = NN(output_layer=['ImH', 'ReH', 'ReE', 'ImHt'])
thnewL1.name = 'new-L1'

# %%
tholddo = NN(output_layer=['ImH', 'ReH', 'ReE', 'ImHt'])
tholddo.name = 'old-do'
thnewdo = NN(output_layer=['ImH', 'ReH', 'ReE', 'ImHt'])
thnewdo.name = 'new-do'

# %%
tholdnr = NN(output_layer=['ImH', 'ReH', 'ReE', 'ImHt'])
tholdnr.name = 'old-nr'
thnewnr = NN(output_layer=['ImH', 'ReH', 'ReE', 'ImHt'])
thnewnr.name = 'new-nr'

# %%
thold0 = NN(output_layer=['ImH', 'ReH', 'ReE', 'ImHt'])
thold0.name = 'old-0'

# %%
dirname = 'closure/nets'
netfilename = 'c4_L25'
for k in range(1, 5):
    try:
        tholdL25.nets += torch.load('{}/{}_old-{}.tar'.format(dirname, netfilename, k))
        thnewL25.nets += torch.load('{}/{}_new-{}.tar'.format(dirname, netfilename, k))
    except:
        break
print("Loaded {} nets for {}".format(len(tholdL25.nets), tholdL25.name))
print("Loaded {} nets for {}".format(len(thnewL25.nets), thnewL25.name))
# Out:
# Loaded 80 nets for old-L25
# Loaded 80 nets for new-L25

# %%
for net, mean, std in tholdL25.nets:
    net.eval()
for net, mean, std in thnewL25.nets:
    net.eval()

# %%
dirname = 'closure/nets'
netfilename = 'c4_L1'
for k in range(1, 3):
    try:
        tholdL1.nets += torch.load('{}/{}_old-{}.tar'.format(dirname, netfilename, k))
        thnewL1.nets += torch.load('{}/{}_new-{}.tar'.format(dirname, netfilename, k))
    except:
        break
print("Loaded {} nets for {}".format(len(tholdL1.nets), tholdL1.name))
print("Loaded {} nets for {}".format(len(thnewL1.nets), thnewL1.name))
# Out:
# Loaded 40 nets for old-L1
# Loaded 40 nets for new-L1

# %%
for net, mean, std in tholdL1.nets:
    net.eval()
for net, mean, std in thnewL1.nets:
    net.eval()

# %%
dirname = 'closure/nets'
netfilename = 'c4_nr'
for k in range(1, 3):
    try:
        tholdnr.nets += torch.load('{}/{}_old-{}.tar'.format(dirname, netfilename, k))
        thnewnr.nets += torch.load('{}/{}_new-{}.tar'.format(dirname, netfilename, k))
    except:
        break
print("Loaded {} nets for {}".format(len(tholdnr.nets), tholdnr.name))
print("Loaded {} nets for {}".format(len(thnewnr.nets), thnewnr.name))
# Out:
# Loaded 16 nets for old-nr
# Loaded 16 nets for new-nr

# %%
dirname = 'closure/nets'
netfilename = 'c4'
for k in range(1, 3):
    try:
        thold.nets += torch.load('{}/{}_old-{}.tar'.format(dirname, netfilename, k))
        thnew.nets += torch.load('{}/{}_new-{}.tar'.format(dirname, netfilename, k))
    except:
        break
print("Loaded {} nets for {}".format(len(thold.nets), thold.name))
print("Loaded {} nets for {}".format(len(thnew.nets), thnew.name))
# Out:
# Loaded 80 nets for old
# Loaded 80 nets for new

# %%
for dset in [mockset_XLU,  mockset_XUU,  mockset_XUL,  mockset_AC,  mockset_AUTDVCS]:
    for th in [thold0, tholdL2, thnewL2, th_KM15_4]:
        print(th.name, th.chisq(dset))
# Out:
# old-0 (tensor(81.2494), 24, tensor(3.8425e-08, dtype=torch.float64))
# old-L2 (tensor(22.1810), 24, tensor(0.5685, dtype=torch.float64))
# new-L2 (tensor(23.2635), 24, tensor(0.5043, dtype=torch.float64))
# KM15_4 tensor(25.8753)
# old-0 (tensor(56.4756), 24, tensor(0.0002, dtype=torch.float64))
# old-L2 (tensor(31.1872), 24, tensor(0.1485, dtype=torch.float64))
# new-L2 (tensor(26.0772), 24, tensor(0.3493, dtype=torch.float64))
# KM15_4 tensor(27.3201)
# old-0 (tensor(79.4839), 24, tensor(7.3509e-08, dtype=torch.float64))
# old-L2 (tensor(26.3932), 24, tensor(0.3335, dtype=torch.float64))
# new-L2 (tensor(26.9757), 24, tensor(0.3056, dtype=torch.float64))
# KM15_4 tensor(24.7350)
# old-0 (tensor(52.2452), 24, tensor(0.0007, dtype=torch.float64))
# old-L2 (tensor(28.9329), 24, tensor(0.2227, dtype=torch.float64))
# new-L2 (tensor(24.1570), 24, tensor(0.4527, dtype=torch.float64))
# KM15_4 tensor(22.6892)
# old-0 (tensor(56.6484), 24, tensor(0.0002, dtype=torch.float64))
# old-L2 (tensor(17.5866), 24, tensor(0.8226, dtype=torch.float64))
# new-L2 (tensor(21.9441), 24, tensor(0.5826, dtype=torch.float64))
# KM15_4 tensor(14.1549)

# %%
fig = gplots.CFFt(cffs=['ImH', 'ReH', 'ReE', 'ImHt'], lines=[thnew, thold, th_KM15_4],
                  bands=[thnew, thold])

# %%
fig = gplots.CFFt(cffs=['ImH', 'ReH', 'ReE', 'ImHt'], lines=[thnew, thnewL25, th_KM15_4],
                  bands=[thnew, thnewL25])

# %%
fig = gplots.CFF3(cffs=['ImH', 'ReH', 'ReE', 'ImHt'], lines=[thnewL2, tholdL2, th_KM15_4],
                  bands=[thnewL2, tholdL2])
